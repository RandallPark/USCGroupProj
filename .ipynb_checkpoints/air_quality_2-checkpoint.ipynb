# %% [markdown]
# # Air quality data

# %% [markdown]
# ### Set-up Dependencies

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps

# Google developer API key
from config import gkey


# Configure gmaps
gmaps.configure(api_key=gkey)

# %% [markdown]
# ### Set-up Multi-API Call
# * This data set has 2 years available, so I will create two API calls and add all the date into a single datafram

# %%
# The data has 2 years
years = [2014, 2017]
# The endpoint will require I specify the year
url =  "https://usc.data.socrata.com/resource/bhyw-mxf5.json?$where=year="

# %% [markdown]
# ### Save JSON data into Lists (pre-dataframe step)

# %%
# Initialize a list that will eventually be used for form the columns in dataframe.
count = []
dataset = []
date = []
geoid = []
location = []
lat = []
lng = []
neighborhood = []
policy_area = []
row_id = []
tract = []
tract_number = []
variable = []
year = []


for yr in years:
    query_url = f"{url}{yr}"
    response = requests.get(query_url)
    response_json = response.json()
    
    for key in range(len(response_json)):
        count.append(response_json[key]['count'])
        dataset.append(response_json[key]['dataset'])
        date.append(response_json[key]['date'])
        geoid.append(response_json[key]['geoid'])
        location.append(response_json[key]['location'])
        neighborhood.append(response_json[key]['neighborhood'])
        policy_area.append(response_json[key]['policy_area'])
        row_id.append(response_json[key]['row_id'])
        tract.append(response_json[key]['tract'])
        tract_number.append(response_json[key]['tract_number'])
        variable.append(response_json[key]['variable'])
        year.append(response_json[key]['year'])

# %% [markdown]
# ### Split location column into lat and lng columns
# * Having lat and logitudinal data will be useful for map visualization

# %%
# Split the location list into two lists, one for lat and one for long data
for i in range(len(location)):
    first = location[i].index(location[i][1])
    last = location[i].index(location[i][-1])
    unpacked = location[i][first:last]
    split_location = unpacked.split(",")
    lat.append(split_location[0])
    lng.append(split_location[1])

# %% [markdown]
# ### Create Dataframe
# * Create a dictionary that contains the list of data from the JSON data, and a label
# * Pass the dict object into pd.DataFrame, and create a pandas object

# %%
dict = {"year" : year,
        "count" : count,
       "dataset" : dataset,
       "date" :  date,
       "geoid" : geoid,
       "location" : location,
        "lat" : lat,
        "lng" : lng,
        "neighborhood" : neighborhood,
        "policy area" : policy_area,
        "row id": row_id,
        "tract" : tract,
        "tract number" : tract_number,
        "variable" : variable,
       }

df = pd.DataFrame(data = dict)
df
# Out:
#       year        count      dataset                     date  \
# 0     2014  11.04010029  Air Quality  2014-01-01T00:00:00.000
# 1     2014  10.95372448  Air Quality  2014-01-01T00:00:00.000
# 2     2014  11.11423953  Air Quality  2014-01-01T00:00:00.000
# 3     2014  11.14308442  Air Quality  2014-01-01T00:00:00.000
# 4     2014  11.18952698  Air Quality  2014-01-01T00:00:00.000
# 5     2014  11.21675181  Air Quality  2014-01-01T00:00:00.000
# 6     2014  11.28482481  Air Quality  2014-01-01T00:00:00.000
# 7     2014  11.39135727  Air Quality  2014-01-01T00:00:00.000
# 8     2014  11.44396506  Air Quality  2014-01-01T00:00:00.000
# 9     2014  11.16243397  Air Quality  2014-01-01T00:00:00.000
# 10    2014  10.86473422  Air Quality  2014-01-01T00:00:00.000
# 11    2014  10.97416477  Air Quality  2014-01-01T00:00:00.000
# 12    2014  10.80761263  Air Quality  2014-01-01T00:00:00.000
# 13    2014  10.94978856  Air Quality  2014-01-01T00:00:00.000
# 14    2014   11.0556707  Air Quality  2014-01-01T00:00:00.000
# 15    2014  10.60618348  Air Quality  2014-01-01T00:00:00.000
# 16    2014   10.6415366  Air Quality  2014-01-01T00:00:00.000
# 17    2014  10.68761951  Air Quality  2014-01-01T00:00:00.000
# 18    2014  10.58812977  Air Quality  2014-01-01T00:00:00.000
# 19    2014  10.50507149  Air Quality  2014-01-01T00:00:00.000
# 20    2014  10.59443142  Air Quality  2014-01-01T00:00:00.000
# 21    2014  10.52210187  Air Quality  2014-01-01T00:00:00.000
# 22    2014  10.57817848  Air Quality  2014-01-01T00:00:00.000
# 23    2014  10.63492965  Air Quality  2014-01-01T00:00:00.000
# 24    2014  10.66524942  Air Quality  2014-01-01T00:00:00.000
# 25    2014  10.74461497  Air Quality  2014-01-01T00:00:00.000
# 26    2014   10.7079786  Air Quality  2014-01-01T00:00:00.000
# 27    2014  10.80162287  Air Quality  2014-01-01T00:00:00.000
# 28    2014  10.76935849  Air Quality  2014-01-01T00:00:00.000
# 29    2014  10.78609168  Air Quality  2014-01-01T00:00:00.000
# ...    ...          ...          ...                      ...
# 1970  2017        11.21  Air Quality  2017-01-01T00:00:00.000
# 1971  2017        11.21  Air Quality  2017-01-01T00:00:00.000
# 1972  2017        11.21  Air Quality  2017-01-01T00:00:00.000
# 1973  2017        11.21  Air Quality  2017-01-01T00:00:00.000
# 1974  2017        11.21  Air Quality  2017-01-01T00:00:00.000
# 1975  2017        11.21  Air Quality  2017-01-01T00:00:00.000
# 1976  2017        11.21  Air Quality  2017-01-01T00:00:00.000
# 1977  2017        11.21  Air Quality  2017-01-01T00:00:00.000
# 1978  2017        11.21  Air Quality  2017-01-01T00:00:00.000
# 1979  2017        11.21  Air Quality  2017-01-01T00:00:00.000
# 1980  2017        11.21  Air Quality  2017-01-01T00:00:00.000
# 1981  2017        11.21  Air Quality  2017-01-01T00:00:00.000
# 1982  2017        11.21  Air Quality  2017-01-01T00:00:00.000
# 1983  2017        11.21  Air Quality  2017-01-01T00:00:00.000
# 1984  2017        11.21  Air Quality  2017-01-01T00:00:00.000
# 1985  2017        11.21  Air Quality  2017-01-01T00:00:00.000
# 1986  2017        10.79  Air Quality  2017-01-01T00:00:00.000
# 1987  2017        11.21  Air Quality  2017-01-01T00:00:00.000
# 1988  2017        10.79  Air Quality  2017-01-01T00:00:00.000
# 1989  2017        11.21  Air Quality  2017-01-01T00:00:00.000
# 1990  2017        11.21  Air Quality  2017-01-01T00:00:00.000
# 1991  2017        11.21  Air Quality  2017-01-01T00:00:00.000
# 1992  2017        11.21  Air Quality  2017-01-01T00:00:00.000
# 1993  2017        11.63  Air Quality  2017-01-01T00:00:00.000
# 1994  2017        11.63  Air Quality  2017-01-01T00:00:00.000
# 1995  2017        11.63  Air Quality  2017-01-01T00:00:00.000
# 1996  2017        11.63  Air Quality  2017-01-01T00:00:00.000
# 1997  2017        11.63  Air Quality  2017-01-01T00:00:00.000
# 1998  2017        12.05  Air Quality  2017-01-01T00:00:00.000
# 1999  2017        12.05  Air Quality  2017-01-01T00:00:00.000
#
#                      geoid                     location          lat  \
# 0     1400000US06037101110    (34.2595555, -118.293602)   34.2595555
# 1     1400000US06037101122      (34.267357, -118.29024)    34.267357
# 2     1400000US06037101210    (34.251998, -118.2926875)    34.251998
# 3     1400000US06037101220    (34.2511895, -118.281014)   34.2511895
# 4     1400000US06037101300    (34.2455945, -118.271731)   34.2455945
# 5     1400000US06037101400     (34.244255, -118.296428)    34.244255
# 6     1400000US06037102103     (34.224155, -118.354339)    34.224155
# 7     1400000US06037102104    (34.216189, -118.3456235)    34.216189
# 8     1400000US06037102105    (34.210852, -118.3480495)    34.210852
# 9     1400000US06037102107   (34.2412955, -118.3292705)   34.2412955
# 10    1400000US06037103101      (34.274431, -118.30714)    34.274431
# 11    1400000US06037103102      (34.262834, -118.30683)    34.262834
# 12    1400000US06037103200   (34.2745565, -118.3439025)   34.2745565
# 13    1400000US06037103300    (34.255439, -118.3527775)    34.255439
# 14    1400000US06037103400    (34.253933, -118.3147245)    34.253933
# 15    1400000US06037104103   (34.2819045, -118.3918905)   34.2819045
# 16    1400000US06037104105     (34.276146, -118.404645)    34.276146
# 17    1400000US06037104108     (34.271671, -118.397614)    34.271671
# 18    1400000US06037104124     (34.287866, -118.376208)    34.287866
# 19    1400000US06037104201   (34.2867415, -118.4160805)   34.2867415
# 20    1400000US06037104203     (34.279058, -118.411554)    34.279058
# 21    1400000US06037104204    (34.2886315, -118.396898)   34.2886315
# 22    1400000US06037104310   (34.2762555, -118.4293915)   34.2762555
# 23    1400000US06037104320     (34.27316, -118.4202235)     34.27316
# 24    1400000US06037104401    (34.2670615, -118.433071)   34.2670615
# 25    1400000US06037104403   (34.2589085, -118.4345385)   34.2589085
# 26    1400000US06037104404   (34.2639205, -118.4286915)   34.2639205
# 27    1400000US06037104500     (34.25551, -118.4257485)     34.25551
# 28    1400000US06037104610   (34.2604335, -118.4189955)   34.2604335
# 29    1400000US06037104620    (34.2579045, -118.422465)   34.2579045
# ...                    ...                          ...          ...
# 1970  1400000US06037296401   (33.7417575, -118.3143515)   33.7417575
# 1971  1400000US06037296402    (33.7455135, -118.303183)   33.7455135
# 1972  1400000US06037296500   (33.7480855, -118.2929285)   33.7480855
# 1973  1400000US06037296600     (33.739883, -118.292314)    33.739883
# 1974  1400000US06037296901    (33.730163, -118.2945655)    33.730163
# 1975  1400000US06037296902   (33.7351435, -118.2945475)   33.7351435
# 1976  1400000US06037297000    (33.7324785, -118.310758)   33.7324785
# 1977  1400000US06037297110    (33.7346615, -118.284188)   33.7346615
# 1978  1400000US06037297120     (33.727169, -118.284224)    33.727169
# 1979  1400000US06037297201   (33.7247115, -118.2912825)   33.7247115
# 1980  1400000US06037297202     (33.724736, -118.299008)    33.724736
# 1981  1400000US06037297300  (33.72072214, -118.3123083)  33.72072214
# 1982  1400000US06037297400   (33.7262015, -118.3220603)   33.7262015
# 1983  1400000US06037297500    (33.713354, -118.3018828)    33.713354
# 1984  1400000US06037297601  (33.71456779, -118.2879352)  33.71456779
# 1985  1400000US06037297602   (33.7162305, -118.2903905)   33.7162305
# 1986  1400000US06037300100     (34.240611, -118.235107)    34.240611
# 1987  1400000US06037300200     (34.228725, -118.237835)    34.228725
# 1988  1400000US06037300301    (34.248378, -118.2527395)    34.248378
# 1989  1400000US06037300400      (34.228257, -118.25731)    34.228257
# 1990  1400000US06037300501    (34.2212985, -118.239588)   34.2212985
# 1991  1400000US06037300502    (34.2117495, -118.225292)   34.2117495
# 1992  1400000US06037300600   (34.2067165, -118.2368375)   34.2067165
# 1993  1400000US06037300701    (34.202483, -118.2588315)    34.202483
# 1994  1400000US06037300702   (34.1907305, -118.2577215)   34.1907305
# 1995  1400000US06037300800    (34.1850915, -118.219529)   34.1850915
# 1996  1400000US06037300901    (34.1693925, -118.206797)   34.1693925
# 1997  1400000US06037300902     (34.155939, -118.203587)    34.155939
# 1998  1400000US06037301000   (34.1564305, -118.2329335)   34.1564305
# 1999  1400000US06037301100   (34.1621815, -118.2441095)   34.1621815
#
#                 lng           neighborhood  policy area  \
# 0       -118.293602                Tujunga  Environment
# 1        -118.29024                Tujunga  Environment
# 2      -118.2926875                Tujunga  Environment
# 3       -118.281014                Tujunga  Environment
# 4       -118.271731                Tujunga  Environment
# 5       -118.296428                Tujunga  Environment
# 6       -118.354339           Shadow Hills  Environment
# 7      -118.3456235           Shadow Hills  Environment
# 8      -118.3480495             Sun Valley  Environment
# 9      -118.3292705           Shadow Hills  Environment
# 10       -118.30714                Sunland  Environment
# 11       -118.30683                Sunland  Environment
# 12     -118.3439025      Lake View Terrace  Environment
# 13     -118.3527775           Shadow Hills  Environment
# 14     -118.3147245                Sunland  Environment
# 15     -118.3918905      Lake View Terrace  Environment
# 16      -118.404645                Pacoima  Environment
# 17      -118.397614                Pacoima  Environment
# 18      -118.376208    Lopez/Kagel Canyons  Environment
# 19     -118.4160805                Pacoima  Environment
# 20      -118.411554                Pacoima  Environment
# 21      -118.396898      Lake View Terrace  Environment
# 22     -118.4293915                Pacoima  Environment
# 23     -118.4202235                Pacoima  Environment
# 24      -118.433071                Pacoima  Environment
# 25     -118.4345385                Pacoima  Environment
# 26     -118.4286915                Pacoima  Environment
# 27     -118.4257485                Pacoima  Environment
# 28     -118.4189955                Pacoima  Environment
# 29      -118.422465                Pacoima  Environment
# ...             ...                    ...          ...
# 1970   -118.3143515              San Pedro  Environment
# 1971    -118.303183              San Pedro  Environment
# 1972   -118.2929285              San Pedro  Environment
# 1973    -118.292314              San Pedro  Environment
# 1974   -118.2945655              San Pedro  Environment
# 1975   -118.2945475              San Pedro  Environment
# 1976    -118.310758              San Pedro  Environment
# 1977    -118.284188              San Pedro  Environment
# 1978    -118.284224              San Pedro  Environment
# 1979   -118.2912825              San Pedro  Environment
# 1980    -118.299008              San Pedro  Environment
# 1981   -118.3123083              San Pedro  Environment
# 1982   -118.3220603              San Pedro  Environment
# 1983   -118.3018828              San Pedro  Environment
# 1984   -118.2879352              San Pedro  Environment
# 1985   -118.2903905              San Pedro  Environment
# 1986    -118.235107  La Crescenta-Montrose  Environment
# 1987    -118.237835  La Crescenta-Montrose  Environment
# 1988   -118.2527395               Glendale  Environment
# 1989     -118.25731               Glendale  Environment
# 1990    -118.239588  La Crescenta-Montrose  Environment
# 1991    -118.225292  La Crescenta-Montrose  Environment
# 1992   -118.2368375               Glendale  Environment
# 1993   -118.2588315               Glendale  Environment
# 1994   -118.2577215               Glendale  Environment
# 1995    -118.219529               Glendale  Environment
# 1996    -118.206797               Glendale  Environment
# 1997    -118.203587               Glendale  Environment
# 1998   -118.2329335               Glendale  Environment
# 1999   -118.2441095               Glendale  Environment
#
#                                              row id  \
# 0     PM2.5_Concentration_2014_1400000US06037101110
# 1     PM2.5_Concentration_2014_1400000US06037101122
# 2     PM2.5_Concentration_2014_1400000US06037101210
# 3     PM2.5_Concentration_2014_1400000US06037101220
# 4     PM2.5_Concentration_2014_1400000US06037101300
# 5     PM2.5_Concentration_2014_1400000US06037101400
# 6     PM2.5_Concentration_2014_1400000US06037102103
# 7     PM2.5_Concentration_2014_1400000US06037102104
# 8     PM2.5_Concentration_2014_1400000US06037102105
# 9     PM2.5_Concentration_2014_1400000US06037102107
# 10    PM2.5_Concentration_2014_1400000US06037103101
# 11    PM2.5_Concentration_2014_1400000US06037103102
# 12    PM2.5_Concentration_2014_1400000US06037103200
# 13    PM2.5_Concentration_2014_1400000US06037103300
# 14    PM2.5_Concentration_2014_1400000US06037103400
# 15    PM2.5_Concentration_2014_1400000US06037104103
# 16    PM2.5_Concentration_2014_1400000US06037104105
# 17    PM2.5_Concentration_2014_1400000US06037104108
# 18    PM2.5_Concentration_2014_1400000US06037104124
# 19    PM2.5_Concentration_2014_1400000US06037104201
# 20    PM2.5_Concentration_2014_1400000US06037104203
# 21    PM2.5_Concentration_2014_1400000US06037104204
# 22    PM2.5_Concentration_2014_1400000US06037104310
# 23    PM2.5_Concentration_2014_1400000US06037104320
# 24    PM2.5_Concentration_2014_1400000US06037104401
# 25    PM2.5_Concentration_2014_1400000US06037104403
# 26    PM2.5_Concentration_2014_1400000US06037104404
# 27    PM2.5_Concentration_2014_1400000US06037104500
# 28    PM2.5_Concentration_2014_1400000US06037104610
# 29    PM2.5_Concentration_2014_1400000US06037104620
# ...                                             ...
# 1970  PM2.5_Concentration_2017_1400000US06037296401
# 1971  PM2.5_Concentration_2017_1400000US06037296402
# 1972  PM2.5_Concentration_2017_1400000US06037296500
# 1973  PM2.5_Concentration_2017_1400000US06037296600
# 1974  PM2.5_Concentration_2017_1400000US06037296901
# 1975  PM2.5_Concentration_2017_1400000US06037296902
# 1976  PM2.5_Concentration_2017_1400000US06037297000
# 1977  PM2.5_Concentration_2017_1400000US06037297110
# 1978  PM2.5_Concentration_2017_1400000US06037297120
# 1979  PM2.5_Concentration_2017_1400000US06037297201
# 1980  PM2.5_Concentration_2017_1400000US06037297202
# 1981  PM2.5_Concentration_2017_1400000US06037297300
# 1982  PM2.5_Concentration_2017_1400000US06037297400
# 1983  PM2.5_Concentration_2017_1400000US06037297500
# 1984  PM2.5_Concentration_2017_1400000US06037297601
# 1985  PM2.5_Concentration_2017_1400000US06037297602
# 1986  PM2.5_Concentration_2017_1400000US06037300100
# 1987  PM2.5_Concentration_2017_1400000US06037300200
# 1988  PM2.5_Concentration_2017_1400000US06037300301
# 1989  PM2.5_Concentration_2017_1400000US06037300400
# 1990  PM2.5_Concentration_2017_1400000US06037300501
# 1991  PM2.5_Concentration_2017_1400000US06037300502
# 1992  PM2.5_Concentration_2017_1400000US06037300600
# 1993  PM2.5_Concentration_2017_1400000US06037300701
# 1994  PM2.5_Concentration_2017_1400000US06037300702
# 1995  PM2.5_Concentration_2017_1400000US06037300800
# 1996  PM2.5_Concentration_2017_1400000US06037300901
# 1997  PM2.5_Concentration_2017_1400000US06037300902
# 1998  PM2.5_Concentration_2017_1400000US06037301000
# 1999  PM2.5_Concentration_2017_1400000US06037301100
#
#                                                   tract tract number  \
# 0     Census Tract 1011.10, Los Angeles County, Cali...       101110
# 1     Census Tract 1011.22, Los Angeles County, Cali...       101122
# 2     Census Tract 1012.10, Los Angeles County, Cali...       101210
# 3     Census Tract 1012.20, Los Angeles County, Cali...       101220
# 4     Census Tract 1013, Los Angeles County, California       101300
# 5     Census Tract 1014, Los Angeles County, California       101400
# 6     Census Tract 1021.03, Los Angeles County, Cali...       102103
# 7     Census Tract 1021.04, Los Angeles County, Cali...       102104
# 8     Census Tract 1021.05, Los Angeles County, Cali...       102105
# 9     Census Tract 1021.07, Los Angeles County, Cali...       102107
# 10    Census Tract 1031.01, Los Angeles County, Cali...       103101
# 11    Census Tract 1031.02, Los Angeles County, Cali...       103102
# 12    Census Tract 1032, Los Angeles County, California       103200
# 13    Census Tract 1033, Los Angeles County, California       103300
# 14    Census Tract 1034, Los Angeles County, California       103400
# 15    Census Tract 1041.03, Los Angeles County, Cali...       104103
# 16    Census Tract 1041.05, Los Angeles County, Cali...       104105
# 17    Census Tract 1041.08, Los Angeles County, Cali...       104108
# 18    Census Tract 1041.24, Los Angeles County, Cali...       104124
# 19    Census Tract 1042.01, Los Angeles County, Cali...       104201
# 20    Census Tract 1042.03, Los Angeles County, Cali...       104203
# 21    Census Tract 1042.04, Los Angeles County, Cali...       104204
# 22    Census Tract 1043.10, Los Angeles County, Cali...       104310
# 23    Census Tract 1043.20, Los Angeles County, Cali...       104320
# 24    Census Tract 1044.01, Los Angeles County, Cali...       104401
# 25    Census Tract 1044.03, Los Angeles County, Cali...       104403
# 26    Census Tract 1044.04, Los Angeles County, Cali...       104404
# 27    Census Tract 1045, Los Angeles County, California       104500
# 28    Census Tract 1046.10, Los Angeles County, Cali...       104610
# 29    Census Tract 1046.20, Los Angeles County, Cali...       104620
# ...                                                 ...          ...
# 1970  Census Tract 2964.01, Los Angeles County, Cali...       296401
# 1971  Census Tract 2964.02, Los Angeles County, Cali...       296402
# 1972  Census Tract 2965, Los Angeles County, California       296500
# 1973  Census Tract 2966, Los Angeles County, California       296600
# 1974  Census Tract 2969.01, Los Angeles County, Cali...       296901
# 1975  Census Tract 2969.02, Los Angeles County, Cali...       296902
# 1976  Census Tract 2970, Los Angeles County, California       297000
# 1977  Census Tract 2971.10, Los Angeles County, Cali...       297110
# 1978  Census Tract 2971.20, Los Angeles County, Cali...       297120
# 1979  Census Tract 2972.01, Los Angeles County, Cali...       297201
# 1980  Census Tract 2972.02, Los Angeles County, Cali...       297202
# 1981  Census Tract 2973, Los Angeles County, California       297300
# 1982  Census Tract 2974, Los Angeles County, California       297400
# 1983  Census Tract 2975, Los Angeles County, California       297500
# 1984  Census Tract 2976.01, Los Angeles County, Cali...       297601
# 1985  Census Tract 2976.02, Los Angeles County, Cali...       297602
# 1986  Census Tract 3001, Los Angeles County, California       300100
# 1987  Census Tract 3002, Los Angeles County, California       300200
# 1988  Census Tract 3003.01, Los Angeles County, Cali...       300301
# 1989  Census Tract 3004, Los Angeles County, California       300400
# 1990  Census Tract 3005.01, Los Angeles County, Cali...       300501
# 1991  Census Tract 3005.02, Los Angeles County, Cali...       300502
# 1992  Census Tract 3006, Los Angeles County, California       300600
# 1993  Census Tract 3007.01, Los Angeles County, Cali...       300701
# 1994  Census Tract 3007.02, Los Angeles County, Cali...       300702
# 1995  Census Tract 3008, Los Angeles County, California       300800
# 1996  Census Tract 3009.01, Los Angeles County, Cali...       300901
# 1997  Census Tract 3009.02, Los Angeles County, Cali...       300902
# 1998  Census Tract 3010, Los Angeles County, California       301000
# 1999  Census Tract 3011, Los Angeles County, California       301100
#
#                  variable
# 0     PM2.5 Concentration
# 1     PM2.5 Concentration
# 2     PM2.5 Concentration
# 3     PM2.5 Concentration
# 4     PM2.5 Concentration
# 5     PM2.5 Concentration
# 6     PM2.5 Concentration
# 7     PM2.5 Concentration
# 8     PM2.5 Concentration
# 9     PM2.5 Concentration
# 10    PM2.5 Concentration
# 11    PM2.5 Concentration
# 12    PM2.5 Concentration
# 13    PM2.5 Concentration
# 14    PM2.5 Concentration
# 15    PM2.5 Concentration
# 16    PM2.5 Concentration
# 17    PM2.5 Concentration
# 18    PM2.5 Concentration
# 19    PM2.5 Concentration
# 20    PM2.5 Concentration
# 21    PM2.5 Concentration
# 22    PM2.5 Concentration
# 23    PM2.5 Concentration
# 24    PM2.5 Concentration
# 25    PM2.5 Concentration
# 26    PM2.5 Concentration
# 27    PM2.5 Concentration
# 28    PM2.5 Concentration
# 29    PM2.5 Concentration
# ...                   ...
# 1970  PM2.5 Concentration
# 1971  PM2.5 Concentration
# 1972  PM2.5 Concentration
# 1973  PM2.5 Concentration
# 1974  PM2.5 Concentration
# 1975  PM2.5 Concentration
# 1976  PM2.5 Concentration
# 1977  PM2.5 Concentration
# 1978  PM2.5 Concentration
# 1979  PM2.5 Concentration
# 1980  PM2.5 Concentration
# 1981  PM2.5 Concentration
# 1982  PM2.5 Concentration
# 1983  PM2.5 Concentration
# 1984  PM2.5 Concentration
# 1985  PM2.5 Concentration
# 1986  PM2.5 Concentration
# 1987  PM2.5 Concentration
# 1988  PM2.5 Concentration
# 1989  PM2.5 Concentration
# 1990  PM2.5 Concentration
# 1991  PM2.5 Concentration
# 1992  PM2.5 Concentration
# 1993  PM2.5 Concentration
# 1994  PM2.5 Concentration
# 1995  PM2.5 Concentration
# 1996  PM2.5 Concentration
# 1997  PM2.5 Concentration
# 1998  PM2.5 Concentration
# 1999  PM2.5 Concentration
#
# [2000 rows x 14 columns]

# %% [markdown]
# ### Format and Clean Data for Further Analysis
# * Convert columns to appropriate data types
# * For data imported as strings, remove white space, and misc characters.

# %%
# Convert the following column from string to floats. 
# The count column contains pollution data.
# Location, lat and lng to be used for mapping and other analysis

df["count"] = pd.to_numeric(df["count"])
df["lat"] = pd.to_numeric(df["lat"])
df["lng"] = pd.to_numeric(df["lng"])

df.head()
# Out:
#    year      count      dataset                     date  \
# 0  2014  11.040100  Air Quality  2014-01-01T00:00:00.000
# 1  2014  10.953724  Air Quality  2014-01-01T00:00:00.000
# 2  2014  11.114240  Air Quality  2014-01-01T00:00:00.000
# 3  2014  11.143084  Air Quality  2014-01-01T00:00:00.000
# 4  2014  11.189527  Air Quality  2014-01-01T00:00:00.000
#
#                   geoid                   location        lat         lng  \
# 0  1400000US06037101110  (34.2595555, -118.293602)  34.259555 -118.293602
# 1  1400000US06037101122    (34.267357, -118.29024)  34.267357 -118.290240
# 2  1400000US06037101210  (34.251998, -118.2926875)  34.251998 -118.292687
# 3  1400000US06037101220  (34.2511895, -118.281014)  34.251190 -118.281014
# 4  1400000US06037101300  (34.2455945, -118.271731)  34.245595 -118.271731
#
#   neighborhood  policy area                                         row id  \
# 0      Tujunga  Environment  PM2.5_Concentration_2014_1400000US06037101110
# 1      Tujunga  Environment  PM2.5_Concentration_2014_1400000US06037101122
# 2      Tujunga  Environment  PM2.5_Concentration_2014_1400000US06037101210
# 3      Tujunga  Environment  PM2.5_Concentration_2014_1400000US06037101220
# 4      Tujunga  Environment  PM2.5_Concentration_2014_1400000US06037101300
#
#                                                tract tract number  \
# 0  Census Tract 1011.10, Los Angeles County, Cali...       101110
# 1  Census Tract 1011.22, Los Angeles County, Cali...       101122
# 2  Census Tract 1012.10, Los Angeles County, Cali...       101210
# 3  Census Tract 1012.20, Los Angeles County, Cali...       101220
# 4  Census Tract 1013, Los Angeles County, California       101300
#
#               variable
# 0  PM2.5 Concentration
# 1  PM2.5 Concentration
# 2  PM2.5 Concentration
# 3  PM2.5 Concentration
# 4  PM2.5 Concentration

# %% [markdown]
# ###  Aggregate Data by Year

# %%
# Aggregate by neighborhood and generate columns for lat, long, and pollution counts.
aggregated_data = df.groupby("neighborhood")["count"].agg(["min", "max", "mean"])

# Create an array for the mean pollution per city
pollution_mean = np.array(aggregated_data["count"]["mean"])

# Create an array for the lat and log for each neighborhood
neighborhood_lat = np.array(aggregated_data["lat"]["min"])
neighborhood_lng = np.array(aggregated_data["lng"]["min"])
# Out:
#                               min        max       mean
# neighborhood
# Adams-Normandie         12.610655  12.890000  12.756371
# Arleta                  10.755628  11.210000  11.061893
# Arlington Heights       12.550961  12.890000  12.727205
# Atwater Village         12.202552  12.470000  12.380503
# Baldwin Hills/Crenshaw  12.050000  12.592871  12.370973
# Bel-Air                 11.630000  11.930089  11.780045
# Beverly Crest           11.630000  12.030324  11.814591
# Beverly Grove           12.050000  12.408499  12.202593
# Beverly Hills           12.050000  12.086217  12.068108
# Beverlywood             12.050000  12.423826  12.236913
# Boyle Heights           12.652629  12.890000  12.791653
# Brentwood               11.210000  12.191123  11.869315
# Broadway-Manchester     12.050000  12.612497  12.306320
# Canoga Park             10.370000  10.776723  10.495761
# Carthay                 12.050000  12.441654  12.244970
# Central-Alameda         12.470000  12.890000  12.769400
# Century City            12.050000  12.328451  12.189226
# Chatsworth               9.955483  10.396813  10.231992
# Chatsworth Reservoir     9.955483  10.245630  10.100556
# Chesterfield Square     12.050000  12.638799  12.412400
# Cheviot Hills           12.050000  12.402661  12.220887
# Chinatown               12.589876  12.890000  12.752877
# Cypress Park            12.472499  12.890000  12.699746
# Del Rey                 12.050000  12.483743  12.248658
# Downtown                12.614443  12.890000  12.768422
# Eagle Rock              11.630000  12.370600  12.076539
# East Hollywood          12.374057  12.890000  12.664691
# Echo Park               12.485330  12.890000  12.717034
# El Sereno               11.630000  12.663224  12.387564
# Elysian Park            12.603991  12.890000  12.746996
# ...                           ...        ...        ...
# Sherman Oaks            11.210000  12.050000  11.514460
# Silver Lake             12.425035  12.890000  12.682148
# South Park              12.669169  12.890000  12.783782
# Studio City             11.778051  12.050000  11.977894
# Sun Valley              11.048415  12.050000  11.633382
# Sunland                 10.864734  11.630000  11.157428
# Sylmar                   9.952894  11.210000  10.667904
# Tarzana                 10.370000  11.400499  10.766484
# Toluca Lake             11.871267  12.050000  11.977233
# Tujunga                 10.953724  11.630000  11.194786
# University Park         12.632059  12.890000  12.767333
# Valley Glen             11.210000  12.050000  11.538287
# Valley Village          11.669030  12.050000  11.883605
# Van Nuys                10.790000  11.435217  11.201344
# Venice                  12.050000  12.376536  12.190270
# Vermont Knolls          12.050000  12.641728  12.339845
# Vermont Square          12.470000  12.890000  12.748720
# Vermont Vista           12.050000  12.608880  12.307341
# Vermont-Slauson         12.050000  12.890000  12.508495
# Watts                   12.050000  12.600087  12.308288
# West Adams              12.050000  12.571092  12.368714
# West Hills               9.955483  10.681408  10.419982
# West Los Angeles        12.050000  12.341406  12.185890
# Westchester             12.050000  12.547522  12.268354
# Westlake                12.525473  12.890000  12.734250
# Westwood                11.630000  12.275387  12.116380
# Wilmington              11.210000  11.573567  11.333828
# Windsor Square          12.482567  12.890000  12.691748
# Winnetka                10.370000  10.832735  10.527579
# Woodland Hills          10.370000  11.198696  10.638024
#
# [119 rows x 3 columns]

# %% [markdown]
# ### Visualize Data using Gmaps

# %%
# Store latitude and longitude in locations
locations = df[["lat", "lng"]]

# Plot Heatmap
fig = gmaps.figure()

symbol_layer = gmaps.symbol_layer(locations, fill_color='red', stroke_color='black', scale=2)

# Add layer
fig.add_layer(symbol_layer)

# Display figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %% [markdown]
# ### Determine the relationship between latitude and pollution counts

# %%
# Plot the pollution counts by neighborhood (via their lat) and visualize in gmaps
x = neighborhood_lat
y = pollution_mean
plt.scatter(x, y, c = 'lightblue', edgecolors = "black")
plt.xlabel("Latitude")
plt.ylabel("Pollution Counts (2.5 ppm)")
plt.title(f"City Latitude vs. Pollution")
plt.grid(True)

# Label the neighborhood with the heighest and lowest counts
# X,Y Coordinates for BH and Chatsworth reservoice
boyle_heights_lat = 34.018117
boyle_heights_cnt = 12.791653
chatsworth_res_lat = 34.228206
chatsworth_res_cnt = 10.245630
plt.text(x = boyle_heights_lat, y = boyle_heights_cnt, s = "Boyle Heights", fontsize = 12)
plt.text(chatsworth_res_lat, chatsworth_res_cnt, s = "Chatsworth Reservoir", fontsize = 12)
plt.savefig('lat_vs_pollution.png')

# %% [markdown]
# ### Determine the Covariance
# * Use numpy np.cov() to evaluate
# * a) how the temperature and latitude vary together
# * b) determine the directionality of any association
# * Statistical Principal:
# * The covariance is used to determine the direction of a linear relationship between two variables as follows:
# * If both variables tend to increase or decrease together, the coefficient is positive.
# * If one variable tends to increase as the other decreases, the coefficient is negative.

# %%
x = neighborhood_lat
y = pollution_mean

np.cov(x,y)

# Compute the covariance matrix: covariance_matrix
covariance_matrix = np.cov(x, y)
covariance_matrix

# Extract covariance of latitude and Max Temperature
pol_lav_covariance = covariance_matrix[0,1]
pol_lav_covariance

if (pol_lav_covariance < 0):
    print(f"The covariance for latitude and temperature is {round(pol_lav_covariance,4)}, and is negative. \nThis states that as one variable increases, the other decreases.")
else:
    print(f"The covariance for latitude and temperature is {round(pol_lav_covariance,4)}, is positive. \nThis states that these variable tend to either increase or decrease together.")
# Out:
# The covariance for latitude and temperature is -0.0482, and is negative.
# This states that as one variable increases, the other decreases.

# %% [markdown]
# ### Determine the Pearson Coefficient
# * Use numpy np.corrcoef() to evaluate
# * a) how the temperature and latitude vary together
# * b) Examine the linear relationship between these two variables
#
# * Statistical Principal:
# * Pearson correlation coefficient, also called the Pearson r, is often easier to interpret than the covariance.
# * The strenght of the association depends on how close the value approaches -1 or 1.
# * The directionality of the association depends on whether it is positive or negative.

# %%
# Function that Computes the Pearson correlation coefficient between two arrays.
def pearson_r(x, y):

    # Compute correlation matrix: corr_mat
    corr_mat = np.corrcoef(x, y)

    # Return entry [0,1]
    return corr_mat[0,1]

# Compute Pearson correlation coefficient for I. versicolor: r
r = pearson_r(x, y)

# Print the result
print(r)

if (r < 0):
    print(f"Since r = {round(r,4)}, is negative; as one variable increases, the other decreases.")
    if(r <= -0.75):
        print(f"Since r = {round(r,4)} is close to -1; There is a strong inverse relationship between these two variables.")
if (r > 0):
    print(f"Since r = {round(r,4)}, is positive; both variables increase together, or decrease together.")
    if (r >= 0.75):
        print(f"Since r = {round(r,4)} is close to 1; There is a strong positive relationship between these two variables.")
    else:
        print("There is a weak or no association between both variables.")
# Out:
# -0.5914960694899909
# Since r = -0.5915, is negative; as one variable increases, the other decreases.

# %% [markdown]
# ### Visualize 5 neighborhoods with the higest and lowest pollution and plot in gmap

# %%
# Sort the data by ascending and descending values in the count column and subset into min and max
max_sorted_df = aggregated_data.sort_values(by = ("count", "mean"), ascending = False)
min_sorted_df = aggregated_data.sort_values(by = ("count", "mean"), ascending = True)

# Get the neighborhoods with the highest and lowest pollution counts
neigh_top_counts = max_sorted_df.iloc[0:5]
neigh_low_counts = min_sorted_df.iloc[0:5]

# Further subset the lat and lng for each of these cities and save into a new df
neigh_top_loc = neigh_top_counts[[("lat", "min"), ("lng", "min")]]
neigh_low_loc = neigh_low_counts[[("lat", "min"), ("lng", "min")]]

# %%
# Store latitude and longitude in locations
top_locations = neigh_top_loc[["lat", "lng"]]
low_locations = neigh_low_loc[["lat", "lng"]]

# Plot Heatmap
fig = gmaps.figure()

# Create heat layer
top_layer = gmaps.heatmap_layer(top_locations)
top_marker_layer = gmaps.marker_layer(top_locations, label='high')

low_layer = gmaps.heatmap_layer(low_locations)
low_marker_layer = gmaps.marker_layer(low_locations, label='low')

# Add layer
fig.add_layer(top_layer)
fig.add_layer(top_marker_layer)
fig.add_layer(low_layer)
fig.add_layer(low_marker_layer)

# Display figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %% [markdown]
# ### Visualize the counts in gmaps to highlight distribution of pollution

# %%
# location dataframe
aggregated_loc_data = df.groupby("neighborhood")["lat", "lng"].agg(["min"])


# Create an array for the mean pollution per city
aggregated_pol_data = df.groupby("neighborhood")["count"].agg(["mean"])
aggregated_pol_float = aggregated_pol_data.astype(dtype = "float")
aggregated_pol_series = aggregated_pol_float["mean"]

# %%
# Plot Heatmap
locations = aggregated_loc_data
weights = aggregated_pol_series

fig = gmaps.figure(map_type="SATELLITE")

# # Create heat layer
heat_layer = gmaps.heatmap_layer(locations, weights = weights)

# # Add layer
fig.add_layer(heat_layer)

# # Display figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %% [markdown]
# ### Park Data

# %%
# The endpoint will require I specify the year
park_url =  "https://usc.data.socrata.com/resource/kp5h-fmqh.json?dataset=Parks Access"

query_url_park = f"{park_url}"
response = requests.get(query_url_park)
park_response_json = response.json()
response_json
# Out:
# [{'count': '11.21',
#   'dataset': 'Air Quality',
#   'date': '2017-01-01T00:00:00.000',
#   'geoid': '1400000US06037101110',
#   'location': '(34.2595555, -118.293602)',
#   'neighborhood': 'Tujunga',
#   'policy_area': 'Environment',
#   'row_id': 'PM2.5_Concentration_2017_1400000US06037101110',
#   'tract': 'Census Tract 1011.10, Los Angeles County, California',
#   'tract_number': '101110',
#   'variable': 'PM2.5 Concentration',
#   'year': '2017'},
#  {'count': '11.21',
#   'dataset': 'Air Quality',
#   'date': '2017-01-01T00:00:00.000',
#   'geoid': '1400000US06037101122',
#   'location': '(34.267357, -118.29024)',
#   'neighborhood': 'Tujunga',
#   'policy_area': 'Environment',
#   'row_id': 'PM2.5_Concentration_2017_1400000US06037101122',
#   'tract': 'Census Tract 1011.22, Los Angeles County, California',
#   'tract_number': '101122',
#   'variable': 'PM2.5 Concentration',
#   'year': '2017'},
#  {'count': '11.21',
#   'dataset': 'Air Quality',
#   'date': '2017-01-01T00:00:00.000',
#   'geoid': '1400000US06037101210',
#   'location': '(34.251998, -118.2926875)',
#   'neighborhood': 'Tujunga',
#   'policy_area': 'Environment',
#   'row_id': 'PM2.5_Concentration_2017_1400000US06037101210',
#   'tract': 'Census Tract 1012.10, Los Angeles County, California',
#   'tract_number': '101210',
#   'variable': 'PM2.5 Concentration',
#   'year': '2017'},
#  {'count': '11.21',
#   'dataset': 'Air Quality',
#   'date': '2017-01-01T00:00:00.000',
#   'geoid': '1400000US06037101220',
#   'location': '(34.2511895, -118.281014)',
#   'neighborhood': 'Tujunga',
#   'policy_area': 'Environment',
#   'row_id': 'PM2.5_Concentration_2017_1400000US06037101220',
#   'tract': 'Census Tract 1012.20, Los Angeles County, California',
#   'tract_number': '101220',
#   'variable': 'PM2.5 Concentration',
#   'year': '2017'},
#  {'count': '11.21',
#   'dataset': 'Air Quality',
#   'date': '2017-01-01T00:00:00.000',
#   'geoid': '1400000US06037101300',
#   'location': '(34.2455945, -118.271731)',
#   'neighborhood': 'Tujunga',
#   'policy_area': 'Environment',
#   'row_id': 'PM2.5_Concentration_2017_1400000US06037101300',
#   'tract': 'Census Tract 1013, Los Angeles County, California',
#   'tract_number': '101300',
#   'variable': 'PM2.5 Concentration',
#   'year': '2017'},
#  {'count': '11.63',
#   'dataset': 'Air Quality',
#   'date': '2017-01-01T00:00:00.000',
#   'geoid': '1400000US06037101400',
#   'location': '(34.244255, -118.296428)',
#   'neighborhood': 'Tujunga',
#   'policy_area': 'Environment',
#   'row_id': 'PM2.5_Concentration_2017_1400000US06037101400',
#   'tract': 'Census Tract 1014, Los Angeles County, California',
#   'tract_number': '101400',
#   'variable': 'PM2.5 Concentration',
#   'year': '2017'},
#  {'count': '12.05',
#   'dataset': 'Air Quality',
#   'date': '2017-01-01T00:00:00.000',
#   'geoid': '1400000US06037102103',
#   'location': '(34.224155, -118.354339)',
#   'neighborhood': 'Shadow Hills',
#   'policy_area': 'Environment',
#   'row_id': 'PM2.5_Concentration_2017_1400000US06037102103',
#   'tract': 'Census Tract 1021.03, Los Angeles County, California',
#   'tract_number': '102103',
#   'variable': 'PM2.5 Concentration',
#   'year': '2017'},
#  {'count': '12.05',
#   'dataset': 'Air Quality',
#   'date': '2017-01-01T00:00:00.000',
#   'geoid': '1400000US06037102104',
#   'location': '(34.216189, -118.3456235)',
#   'neighborhood': 'Shadow Hills',
#   'policy_area': 'Environment',
#   'row_id': 'PM2.5_Concentration_2017_1400000US06037102104',
#   'tract': 'Census Tract 1021.04, Los Angeles County, California',
#   'tract_number': '102104',
#   'variable': 'PM2.5 Concentration',
#   'year': '2017'},
#  {'count': '12.05',
#   'dataset': 'Air Quality',
#   'date': '2017-01-01T00:00:00.000',
#   'geoid': '1400000US06037102105',
#   'location': '(34.210852, -118.3480495)',
#   'neighborhood': 'Sun Valley',
#   'policy_area': 'Environment',
#   'row_id': 'PM2.5_Concentration_2017_1400000US06037102105',
#   'tract': 'Census Tract 1021.05, Los Angeles County, California',
#   'tract_number': '102105',
#   'variable': 'PM2.5 Concentration',
#   'year': '2017'},
#  {'count': '11.63',
#   'dataset': 'Air Quality',
#   'date': '2017-01-01T00:00:00.000',
#   'geoid': '1400000US06037102107',
#   'location': '(34.2412955, -118.3292705)',
#   'neighborhood': 'Shadow Hills',
#   'policy_area': 'Environment',
#   'row_id': 'PM2.5_Concentration_2017_1400000US06037102107',
#   'tract': 'Census Tract 1021.07, Los Angeles County, California',
#   'tract_number': '102107',
#   'variable': 'PM2.5 Concentration',
#   'year': '2017'},
#  {'count': '11.21',
#   'dataset': 'Air Quality',
#   'date': '2017-01-01T00:00:00.000',
#   'geoid': '1400000US06037103101',
#   'location': '(34.274431, -118.30714)',
#   'neighborhood': 'Sunland',
#   'policy_area': 'Environment',
#   'row_id': 'PM2.5_Concentration_2017_1400000US06037103101',
#   'tract': 'Census Tract 1031.01, Los Angeles County, California',
#   'tract_number': '103101',
#   'variable': 'PM2.5 Concentration',
#   'year': '2017'},
#  {'count': '11.21',
#   'dataset': 'Air Quality',
#   'date': '2017-01-01T00:00:00.000',
#   'geoid': '1400000US06037103102',
#   'location': '(34.262834, -118.30683)',
#   'neighborhood': 'Sunland',
#   'policy_area': 'Environment',
#   'row_id': 'PM2.5_Concentration_2017_1400000US06037103102',
#   'tract': 'Census Tract 1031.02, Los Angeles County, California',
#   'tract_number': '103102',
#   'variable': 'PM2.5 Concentration',
#   'year': '2017'},
#  {'count': '11.21',
#   'dataset': 'Air Quality',
#   'date': '2017-01-01T00:00:00.000',
#   'geoid': '1400000US06037103200',
#   'location': '(34.2745565, -118.3439025)',
#   'neighborhood': 'Lake View Terrace',
#   'policy_area': 'Environment',
#   'row_id': 'PM2.5_Concentration_2017_1400000US06037103200',
#   'tract': 'Census Tract 1032, Los Angeles County, California',
#   'tract_number': '103200',
#   'variable': 'PM2.5 Concentration',
#   'year': '2017'},
#  {'count': '11.63',
#   'dataset': 'Air Quality',
#   'date': '2017-01-01T00:00:00.000',
#   'geoid': '1400000US06037103300',
#   'location': '(34.255439, -118.3527775)',
#   'neighborhood': 'Shadow Hills',
#   'policy_area': 'Environment',
#   'row_id': 'PM2.5_Concentration_2017_1400000US06037103300',
#   'tract': 'Census Tract 1033, Los Angeles County, California',
#   'tract_number': '103300',
#   'variable': 'PM2.5 Concentration',
#   'year': '2017'},
#  {'count': '11.63',
#   'dataset': 'Air Quality',
#   'date': '2017-01-01T00:00:00.000',
#   'geoid': '1400000US06037103400',
#   'location': '(34.253933, -118.3147245)',
#   'neighborhood': 'Sunland',
#   'policy_area': 'Environment',
#   'row_id': 'PM2.5_Concentration_2017_1400000US06037103400',
#   'tract': 'Census Tract 1034, Los Angeles County, California',
#   'tract_number': '103400',
#   'variable': 'PM2.5 Concentration',
#   'year': '2017'},
#  {'count': '11.21',
#   'dataset': 'Air Quality',
#   'date': '2017-01-01T00:00:00.000',
#   'geoid': '1400000US06037104103',
#   'location': '(34.2819045, -118.3918905)',
#   'neighborhood': 'Lake View Terrace',
#   'policy_area': 'Environment',
#   'row_id': 'PM2.5_Concentration_2017_1400000US06037104103',
#   'tract': 'Census Tract 1041.03, Los Angeles County, California',
#   'tract_number': '104103',
#   'variable': 'PM2.5 Concentration',
#   'year': '2017'},
#  {'count': '11.21',
#   'dataset': 'Air Quality',
#   'date': '2017-01-01T00:00:00.000',
#   'geoid': '1400000US06037104105',
#   'location': '(34.276146, -118.404645)',
#   'neighborhood': 'Pacoima',
#   'policy_area': 'Environment',
#   'row_id': 'PM2.5_Concentration_2017_1400000US06037104105',
#   'tract': 'Census Tract 1041.05, Los Angeles County, California',
#   'tract_number': '104105',
#   'variable': 'PM2.5 Concentration',
#   'year': '2017'},
#  {'count': '11.21',
#   'dataset': 'Air Quality',
#   'date': '2017-01-01T00:00:00.000',
#   'geoid': '1400000US06037104108',
#   'location': '(34.271671, -118.397614)',
#   'neighborhood': 'Pacoima',
#   'policy_area': 'Environment',
#   'row_id': 'PM2.5_Concentration_2017_1400000US06037104108',
#   'tract': 'Census Tract 1041.08, Los Angeles County, California',
#   'tract_number': '104108',
#   'variable': 'PM2.5 Concentration',
#   'year': '2017'},
#  {'count': '11.21',
#   'dataset': 'Air Quality',
#   'date': '2017-01-01T00:00:00.000',
#   'geoid': '1400000US06037104124',
#   'location': '(34.287866, -118.376208)',
#   'neighborhood': 'Lopez/Kagel Canyons',
#   'policy_area': 'Environment',
#   'row_id': 'PM2.5_Concentration_2017_1400000US06037104124',
#   'tract': 'Census Tract 1041.24, Los Angeles County, California',
#   'tract_number': '104124',
#   'variable': 'PM2.5 Concentration',
#   'year': '2017'},
#  {'count': '11.21',
#   'dataset': 'Air Quality',
#   'date': '2017-01-01T00:00:00.000',
#   'geoid': '1400000US06037104201',
#   'location': '(34.2867415, -118.4160805)',
#   'neighborhood': 'Pacoima',
#   'policy_area': 'Environment',
#   'row_id': 'PM2.5_Concentration_2017_1400000US06037104201',
#   'tract': 'Census Tract 1042.01, Los Angeles County, California',
#   'tract_number': '104201',
#   'variable': 'PM2.5 Concentration',
#   'year': '2017'},
#  {'count': '11.21',
#   'dataset': 'Air Quality',
#   'date': '2017-01-01T00:00:00.000',
#   'geoid': '1400000US06037104203',
#   'location': '(34.279058, -118.411554)',
#   'neighborhood': 'Pacoima',
#   'policy_area': 'Environment',
#   'row_id': 'PM2.5_Concentration_2017_1400000US06037104203',
#   'tract': 'Census Tract 1042.03, Los Angeles County, California',
#   'tract_number': '104203',
#   'variable': 'PM2.5 Concentration',
#   'year': '2017'},
#  {'count': '11.21',
#   'dataset': 'Air Quality',
#   'date': '2017-01-01T00:00:00.000',
#   'geoid': '1400000US06037104204',
#   'location': '(34.2886315, -118.396898)',
#   'neighborhood': 'Lake View Terrace',
#   'policy_area': 'Environment',
#   'row_id': 'PM2.5_Concentration_2017_1400000US06037104204',
#   'tract': 'Census Tract 1042.04, Los Angeles County, California',
#   'tract_number': '104204',
#   'variable': 'PM2.5 Concentration',
#   'year': '2017'},
#  {'count': '11.21',
#   'dataset': 'Air Quality',
#   'date': '2017-01-01T00:00:00.000',
#   'geoid': '1400000US06037104310',
#   'location': '(34.2762555, -118.4293915)',
#   'neighborhood': 'Pacoima',
#   'policy_area': 'Environment',
#   'row_id': 'PM2.5_Concentration_2017_1400000US06037104310',
#   'tract': 'Census Tract 1043.10, Los Angeles County, California',
#   'tract_number': '104310',
#   'variable': 'PM2.5 Concentration',
#   'year': '2017'},
#  {'count': '11.21',
#   'dataset': 'Air Quality',
#   'date': '2017-01-01T00:00:00.000',
#   'geoid': '1400000US06037104320',
#   'location': '(34.27316, -118.4202235)',
#   'neighborhood': 'Pacoima',
#   'policy_area': 'Environment',
#   'row_id': 'PM2.5_Concentration_2017_1400000US06037104320',
#   'tract': 'Census Tract 1043.20, Los Angeles County, California',
#   'tract_number': '104320',
#   'variable': 'PM2.5 Concentration',
#   'year': '2017'},
#  {'count': '11.21',
#   'dataset': 'Air Quality',
#   'date': '2017-01-01T00:00:00.000',
#   'geoid': '1400000US06037104401',
#   'location': '(34.2670615, -118.433071)',
#   'neighborhood': 'Pacoima',
#   'policy_area': 'Environment',
#   'row_id': 'PM2.5_Concentration_2017_1400000US06037104401',
#   'tract': 'Census Tract 1044.01, Los Angeles County, California',
#   'tract_number': '104401',
#   'variable': 'PM2.5 Concentration',
#   'year': '2017'},
#  {'count': '11.21',
#   'dataset': 'Air Quality',
#   'date': '2017-01-01T00:00:00.000',
#   'geoid': '1400000US06037104403',
#   'location': '(34.2589085, -118.4345385)',
#   'neighborhood': 'Pacoima',
#   'policy_area': 'Environment',
#   'row_id': 'PM2.5_Concentration_2017_1400000US06037104403',
#   'tract': 'Census Tract 1044.03, Los Angeles County, California',
#   'tract_number': '104403',
#   'variable': 'PM2.5 Concentration',
#   'year': '2017'},
#  {'count': '11.21',
#   'dataset': 'Air Quality',
#   'date': '2017-01-01T00:00:00.000',
#   'geoid': '1400000US06037104404',
#   'location': '(34.2639205, -118.4286915)',
#   'neighborhood': 'Pacoima',
#   'policy_area': 'Environment',
#   'row_id': 'PM2.5_Concentration_2017_1400000US06037104404',
#   'tract': 'Census Tract 1044.04, Los Angeles County, California',
#   'tract_number': '104404',
#   'variable': 'PM2.5 Concentration',
#   'year': '2017'},
#  {'count': '11.21',
#   'dataset': 'Air Quality',
#   'date': '2017-01-01T00:00:00.000',
#   'geoid': '1400000US06037104500',
#   'location': '(34.25551, -118.4257485)',
#   'neighborhood': 'Pacoima',
#   'policy_area': 'Environment',
#   'row_id': 'PM2.5_Concentration_2017_1400000US06037104500',
#   'tract': 'Census Tract 1045, Los Angeles County, California',
#   'tract_number': '104500',
#   'variable': 'PM2.5 Concentration',
#   'year': '2017'},
#  {'count': '11.21',
#   'dataset': 'Air Quality',
#   'date': '2017-01-01T00:00:00.000',
#   'geoid': '1400000US06037104610',
#   'location': '(34.2604335, -118.4189955)',
#   'neighborhood': 'Pacoima',
#   'policy_area': 'Environment',
#   'row_id': 'PM2.5_Concentration_2017_1400000US06037104610',
#   'tract': 'Census Tract 1046.10, Los Angeles County, California',
#   'tract_number': '104610',
#   'variable': 'PM2.5 Concentration',
#   'year': '2017'},
#  {'count': '11.21',
#   'dataset': 'Air Quality',
#   'date': '2017-01-01T00:00:00.000',
#   'geoid': '1400000US06037104620',
#   'location': '(34.2579045, -118.422465)',
#   'neighborhood': 'Pacoima',
#   'policy_area': 'Environment',
#   'row_id': 'PM2.5_Concentration_2017_1400000US06037104620',
#   'tract': 'Census Tract 1046.20, Los Angeles County, California',
#   'tract_number': '104620',
#   'variable': 'PM2.5 Concentration',
#   'year': '2017'},
#  {'count': '11.21',
#   'dataset': 'Air Quality',
#   'date': '2017-01-01T00:00:00.000',
#   'geoid': '1400000US06037104701',
#   'location': '(34.268476, -118.4152165)',
#   'neighborhood': 'Pacoima',
#   'policy_area': 'Environment',
#   'row_id': 'PM2.5_Concentration_2017_1400000US06037104701',
#   'tract': 'Census Tract 1047.01, Los Angeles County, California',
#   'tract_number': '104701',
#   'variable': 'PM2.5 Concentration',
#   'year': '2017'},
#  {'count': '11.63',
#   'dataset': 'Air Quality',
#   'date': '2017-01-01T00:00:00.000',
#   'geoid': '1400000US06037104703',
#   'location': '(34.2551165, -118.399872)',
#   'neighborhood': 'Pacoima',
#   'policy_area': 'Environment',
#   'row_id': 'PM2.5_Concentration_2017_1400000US06037104703',
#   'tract': 'Census Tract 1047.03, Los Angeles County, California',
#   'tract_number': '104703',
#   'variable': 'PM2.5 Concentration',
#   'year': '2017'},
#  {'count': '11.21',
#   'dataset': 'Air Quality',
#   'date': '2017-01-01T00:00:00.000',
#   'geoid': '1400000US06037104704',
#   'location': '(34.2625155, -118.4088415)',
#   'neighborhood': 'Pacoima',
#   'policy_area': 'Environment',
#   'row_id': 'PM2.5_Concentration_2017_1400000US06037104704',
#   'tract': 'Census Tract 1047.04, Los Angeles County, California',
#   'tract_number': '104704',
#   'variable': 'PM2.5 Concentration',
#   'year': '2017'},
#  {'count': '11.21',
#   'dataset': 'Air Quality',
#   'date': '2017-01-01T00:00:00.000',
#   'geoid': '1400000US06037104810',
#   'location': '(34.2502955, -118.411179)',
#   'neighborhood': 'Pacoima',
#   'policy_area': 'Environment',
#   'row_id': 'PM2.5_Concentration_2017_1400000US06037104810',
#   'tract': 'Census Tract 1048.10, Los Angeles County, California',
#   'tract_number': '104810',
#   'variable': 'PM2.5 Concentration',
#   'year': '2017'},
#  {'count': '11.21',
#   'dataset': 'Air Quality',
#   'date': '2017-01-01T00:00:00.000',
#   'geoid': '1400000US06037104821',
#   'location': '(34.2465705, -118.416294)',
#   'neighborhood': 'Pacoima',
#   'policy_area': 'Environment',
#   'row_id': 'PM2.5_Concentration_2017_1400000US06037104821',
#   'tract': 'Census Tract 1048.21, Los Angeles County, California',
#   'tract_number': '104821',
#   'variable': 'PM2.5 Concentration',
#   'year': '2017'},
#  {'count': '11.21',
#   'dataset': 'Air Quality',
#   'date': '2017-01-01T00:00:00.000',
#   'geoid': '1400000US06037104822',
#   'location': '(34.245882, -118.4209225)',
#   'neighborhood': 'Pacoima',
#   'policy_area': 'Environment',
#   'row_id': 'PM2.5_Concentration_2017_1400000US06037104822',
#   'tract': 'Census Tract 1048.22, Los Angeles County, California',
#   'tract_number': '104822',
#   'variable': 'PM2.5 Concentration',
#   'year': '2017'},
#  {'count': '11.21',
#   'dataset': 'Air Quality',
#   'date': '2017-01-01T00:00:00.000',
#   'geoid': '1400000US06037106010',
#   'location': '(34.3231715, -118.444538)',
#   'neighborhood': 'Sylmar',
#   'policy_area': 'Environment',
#   'row_id': 'PM2.5_Concentration_2017_1400000US06037106010',
#   'tract': 'Census Tract 1060.10, Los Angeles County, California',
#   'tract_number': '106010',
#   'variable': 'PM2.5 Concentration',
#   'year': '2017'},
#  {'count': '11.21',
#   'dataset': 'Air Quality',
#   'date': '2017-01-01T00:00:00.000',
#   'geoid': '1400000US06037106020',
#   'location': '(34.320427, -118.428524)',
#   'neighborhood': 'Sylmar',
#   'policy_area': 'Environment',
#   'row_id': 'PM2.5_Concentration_2017_1400000US06037106020',
#   'tract': 'Census Tract 1060.20, Los Angeles County, California',
#   'tract_number': '106020',
#   'variable': 'PM2.5 Concentration',
#   'year': '2017'},
#  {'count': '10.79',
#   'dataset': 'Air Quality',
#   'date': '2017-01-01T00:00:00.000',
#   'geoid': '1400000US06037106111',
#   'location': '(34.3231945, -118.4087995)',
#   'neighborhood': 'Sylmar',
#   'policy_area': 'Environment',
#   'row_id': 'PM2.5_Concentration_2017_1400000US06037106111',
#   'tract': 'Census Tract 1061.11, Los Angeles County, California',
#   'tract_number': '106111',
#   'variable': 'PM2.5 Concentration',
#   'year': '2017'},
#  {'count': '11.21',
#   'dataset': 'Air Quality',
#   'date': '2017-01-01T00:00:00.000',
#   'geoid': '1400000US06037106112',
#   'location': '(34.305005, -118.414298)',
#   'neighborhood': 'Sylmar',
#   'policy_area': 'Environment',
#   'row_id': 'PM2.5_Concentration_2017_1400000US06037106112',
#   'tract': 'Census Tract 1061.12, Los Angeles County, California',
#   'tract_number': '106112',
#   'variable': 'PM2.5 Concentration',
#   'year': '2017'},
#  {'count': '11.21',
#   'dataset': 'Air Quality',
#   'date': '2017-01-01T00:00:00.000',
#   'geoid': '1400000US06037106113',
#   'location': '(34.3062, -118.42203)',
#   'neighborhood': 'Sylmar',
#   'policy_area': 'Environment',
#   'row_id': 'PM2.5_Concentration_2017_1400000US06037106113',
#   'tract': 'Census Tract 1061.13, Los Angeles County, California',
#   'tract_number': '106113',
#   'variable': 'PM2.5 Concentration',
#   'year': '2017'},
#  {'count': '11.21',
#   'dataset': 'Air Quality',
#   'date': '2017-01-01T00:00:00.000',
#   'geoid': '1400000US06037106114',
#   'location': '(34.302675, -118.426951)',
#   'neighborhood': 'Sylmar',
#   'policy_area': 'Environment',
#   'row_id': 'PM2.5_Concentration_2017_1400000US06037106114',
#   'tract': 'Census Tract 1061.14, Los Angeles County, California',
#   'tract_number': '106114',
#   'variable': 'PM2.5 Concentration',
#   'year': '2017'},
#  {'count': '11.21',
#   'dataset': 'Air Quality',
#   'date': '2017-01-01T00:00:00.000',
#   'geoid': '1400000US06037106403',
#   'location': '(34.306005, -118.441288)',
#   'neighborhood': 'Sylmar',
#   'policy_area': 'Environment',
#   'row_id': 'PM2.5_Concentration_2017_1400000US06037106403',
#   'tract': 'Census Tract 1064.03, Los Angeles County, California',
#   'tract_number': '106403',
#   'variable': 'PM2.5 Concentration',
#   'year': '2017'},
#  {'count': '11.21',
#   'dataset': 'Air Quality',
#   'date': '2017-01-01T00:00:00.000',
#   'geoid': '1400000US06037106405',
#   'location': '(34.3146865, -118.448309)',
#   'neighborhood': 'Sylmar',
#   'policy_area': 'Environment',
#   'row_id': 'PM2.5_Concentration_2017_1400000US06037106405',
#   'tract': 'Census Tract 1064.05, Los Angeles County, California',
#   'tract_number': '106405',
#   'variable': 'PM2.5 Concentration',
#   'year': '2017'},
#  {'count': '11.21',
#   'dataset': 'Air Quality',
#   'date': '2017-01-01T00:00:00.000',
#   'geoid': '1400000US06037106406',
#   'location': '(34.321542, -118.4587415)',
#   'neighborhood': 'Sylmar',
#   'policy_area': 'Environment',
#   'row_id': 'PM2.5_Concentration_2017_1400000US06037106406',
#   'tract': 'Census Tract 1064.06, Los Angeles County, California',
#   'tract_number': '106406',
#   'variable': 'PM2.5 Concentration',
#   'year': '2017'},
#  {'count': '11.21',
#   'dataset': 'Air Quality',
#   'date': '2017-01-01T00:00:00.000',
#   'geoid': '1400000US06037106407',
#   'location': '(34.3105765, -118.4365505)',
#   'neighborhood': 'Sylmar',
#   'policy_area': 'Environment',
#   'row_id': 'PM2.5_Concentration_2017_1400000US06037106407',
#   'tract': 'Census Tract 1064.07, Los Angeles County, California',
#   'tract_number': '106407',
#   'variable': 'PM2.5 Concentration',
#   'year': '2017'},
#  {'count': '11.21',
#   'dataset': 'Air Quality',
#   'date': '2017-01-01T00:00:00.000',
#   'geoid': '1400000US06037106408',
#   'location': '(34.3132585, -118.440082)',
#   'neighborhood': 'Sylmar',
#   'policy_area': 'Environment',
#   'row_id': 'PM2.5_Concentration_2017_1400000US06037106408',
#   'tract': 'Census Tract 1064.08, Los Angeles County, California',
#   'tract_number': '106408',
#   'variable': 'PM2.5 Concentration',
#   'year': '2017'},
#  {'count': '10.79',
#   'dataset': 'Air Quality',
#   'date': '2017-01-01T00:00:00.000',
#   'geoid': '1400000US06037106510',
#   'location': '(34.3236325, -118.4860245)',
#   'neighborhood': 'Sylmar',
#   'policy_area': 'Environment',
#   'row_id': 'PM2.5_Concentration_2017_1400000US06037106510',
#   'tract': 'Census Tract 1065.10, Los Angeles County, California',
#   'tract_number': '106510',
#   'variable': 'PM2.5 Concentration',
#   'year': '2017'},
#  {'count': '11.21',
#   'dataset': 'Air Quality',
#   'date': '2017-01-01T00:00:00.000',
#   'geoid': '1400000US06037106520',
#   'location': '(34.308856, -118.4613605)',
#   'neighborhood': 'Sylmar',
#   'policy_area': 'Environment',
#   'row_id': 'PM2.5_Concentration_2017_1400000US06037106520',
#   'tract': 'Census Tract 1065.20, Los Angeles County, California',
#   'tract_number': '106520',
#   'variable': 'PM2.5 Concentration',
#   'year': '2017'},
#  {'count': '10.37',
#   'dataset': 'Air Quality',
#   'date': '2017-01-01T00:00:00.000',
#   'geoid': '1400000US06037106603',
#   'location': '(34.3189225, -118.5218285)',
#   'neighborhood': 'Granada Hills',
#   'policy_area': 'Environment',
#   'row_id': 'PM2.5_Concentration_2017_1400000US06037106603',
#   'tract': 'Census Tract 1066.03, Los Angeles County, California',
#   'tract_number': '106603',
#   'variable': 'PM2.5 Concentration',
#   'year': '2017'},
#  {'count': '10.79',
#   'dataset': 'Air Quality',
#   'date': '2017-01-01T00:00:00.000',
#   'geoid': '1400000US06037106604',
#   'location': '(34.3042795, -118.474247)',
#   'neighborhood': 'Sylmar',
#   'policy_area': 'Environment',
#   'row_id': 'PM2.5_Concentration_2017_1400000US06037106604',
#   'tract': 'Census Tract 1066.04, Los Angeles County, California',
#   'tract_number': '106604',
#   'variable': 'PM2.5 Concentration',
#   'year': '2017'},
#  {'count': '10.37',
#   'dataset': 'Air Quality',
#   'date': '2017-01-01T00:00:00.000',
#   'geoid': '1400000US06037106641',
#   'location': '(34.298025, -118.509153)',
#   'neighborhood': 'Granada Hills',
#   'policy_area': 'Environment',
#   'row_id': 'PM2.5_Concentration_2017_1400000US06037106641',
#   'tract': 'Census Tract 1066.41, Los Angeles County, California',
#   'tract_number': '106641',
#   'variable': 'PM2.5 Concentration',
#   'year': '2017'},
#  {'count': '10.37',
#   'dataset': 'Air Quality',
#   'date': '2017-01-01T00:00:00.000',
#   'geoid': '1400000US06037106642',
#   'location': '(34.2863475, -118.5084525)',
#   'neighborhood': 'Granada Hills',
#   'policy_area': 'Environment',
#   'row_id': 'PM2.5_Concentration_2017_1400000US06037106642',
#   'tract': 'Census Tract 1066.42, Los Angeles County, California',
#   'tract_number': '106642',
#   'variable': 'PM2.5 Concentration',
#   'year': '2017'},
#  {'count': '10.37',
#   'dataset': 'Air Quality',
#   'date': '2017-01-01T00:00:00.000',
#   'geoid': '1400000US06037106643',
#   'location': '(34.289784, -118.524711)',
#   'neighborhood': 'Granada Hills',
#   'policy_area': 'Environment',
#   'row_id': 'PM2.5_Concentration_2017_1400000US06037106643',
#   'tract': 'Census Tract 1066.43, Los Angeles County, California',
#   'tract_number': '106643',
#   'variable': 'PM2.5 Concentration',
#   'year': '2017'},
#  {'count': '10.79',
#   'dataset': 'Air Quality',
#   'date': '2017-01-01T00:00:00.000',
#   'geoid': '1400000US06037106645',
#   'location': '(34.2905125, -118.4928915)',
#   'neighborhood': 'Granada Hills',
#   'policy_area': 'Environment',
#   'row_id': 'PM2.5_Concentration_2017_1400000US06037106645',
#   'tract': 'Census Tract 1066.45, Los Angeles County, California',
#   'tract_number': '106645',
#   'variable': 'PM2.5 Concentration',
#   'year': '2017'},
#  {'count': '10.79',
#   'dataset': 'Air Quality',
#   'date': '2017-01-01T00:00:00.000',
#   'geoid': '1400000US06037106646',
#   'location': '(34.2790905, -118.4941245)',
#   'neighborhood': 'Granada Hills',
#   'policy_area': 'Environment',
#   'row_id': 'PM2.5_Concentration_2017_1400000US06037106646',
#   'tract': 'Census Tract 1066.46, Los Angeles County, California',
#   'tract_number': '106646',
#   'variable': 'PM2.5 Concentration',
#   'year': '2017'},
#  {'count': '11.21',
#   'dataset': 'Air Quality',
#   'date': '2017-01-01T00:00:00.000',
#   'geoid': '1400000US06037106648',
#   'location': '(34.293406, -118.4556035)',
#   'neighborhood': 'Sylmar',
#   'policy_area': 'Environment',
#   'row_id': 'PM2.5_Concentration_2017_1400000US06037106648',
#   'tract': 'Census Tract 1066.48, Los Angeles County, California',
#   'tract_number': '106648',
#   'variable': 'PM2.5 Concentration',
#   'year': '2017'},
#  {'count': '11.21',
#   'dataset': 'Air Quality',
#   'date': '2017-01-01T00:00:00.000',
#   'geoid': '1400000US06037106649',
#   'location': '(34.288747, -118.4611105)',
#   'neighborhood': 'Sylmar',
#   'policy_area': 'Environment',
#   'row_id': 'PM2.5_Concentration_2017_1400000US06037106649',
#   'tract': 'Census Tract 1066.49, Los Angeles County, California',
#   'tract_number': '106649',
#   'variable': 'PM2.5 Concentration',
#   'year': '2017'},
#  {'count': '11.21',
#   'dataset': 'Air Quality',
#   'date': '2017-01-01T00:00:00.000',
#   'geoid': '1400000US06037107010',
#   'location': '(34.302027, -118.446501)',
#   'neighborhood': 'Sylmar',
#   'policy_area': 'Environment',
#   'row_id': 'PM2.5_Concentration_2017_1400000US06037107010',
#   'tract': 'Census Tract 1070.10, Los Angeles County, California',
#   'tract_number': '107010',
#   'variable': 'PM2.5 Concentration',
#   'year': '2017'},
#  {'count': '11.21',
#   'dataset': 'Air Quality',
#   'date': '2017-01-01T00:00:00.000',
#   'geoid': '1400000US06037107020',
#   'location': '(34.2975345, -118.4503905)',
#   'neighborhood': 'Sylmar',
#   'policy_area': 'Environment',
#   'row_id': 'PM2.5_Concentration_2017_1400000US06037107020',
#   'tract': 'Census Tract 1070.20, Los Angeles County, California',
#   'tract_number': '107020',
#   'variable': 'PM2.5 Concentration',
#   'year': '2017'},
#  {'count': '10.37',
#   'dataset': 'Air Quality',
#   'date': '2017-01-01T00:00:00.000',
#   'geoid': '1400000US06037108101',
#   'location': '(34.280038, -118.5413715)',
#   'neighborhood': 'Porter Ranch',
#   'policy_area': 'Environment',
#   'row_id': 'PM2.5_Concentration_2017_1400000US06037108101',
#   'tract': 'Census Tract 1081.01, Los Angeles County, California',
#   'tract_number': '108101',
#   'variable': 'PM2.5 Concentration',
#   'year': '2017'},
#  {'count': '10.37',
#   'dataset': 'Air Quality',
#   'date': '2017-01-01T00:00:00.000',
#   'geoid': '1400000US06037108102',
#   'location': '(34.280795, -118.55492)',
#   'neighborhood': 'Porter Ranch',
#   'policy_area': 'Environment',
#   'row_id': 'PM2.5_Concentration_2017_1400000US06037108102',
#   'tract': 'Census Tract 1081.02, Los Angeles County, California',
#   'tract_number': '108102',
#   'variable': 'PM2.5 Concentration',
#   'year': '2017'},
#  {'count': '10.37',
#   'dataset': 'Air Quality',
#   'date': '2017-01-01T00:00:00.000',
#   'geoid': '1400000US06037108103',
#   'location': '(34.2860705, -118.542893)',
#   'neighborhood': 'Porter Ranch',
#   'policy_area': 'Environment',
#   'row_id': 'PM2.5_Concentration_2017_1400000US06037108103',
#   'tract': 'Census Tract 1081.03, Los Angeles County, California',
#   'tract_number': '108103',
#   'variable': 'PM2.5 Concentration',
#   'year': '2017'},
#  {'count': '10.37',
#   'dataset': 'Air Quality',
#   'date': '2017-01-01T00:00:00.000',
#   'geoid': '1400000US06037108104',
#   'location': '(34.2939525, -118.5470515)',
#   'neighborhood': 'Porter Ranch',
#   'policy_area': 'Environment',
#   'row_id': 'PM2.5_Concentration_2017_1400000US06037108104',
#   'tract': 'Census Tract 1081.04, Los Angeles County, California',
#   'tract_number': '108104',
#   'variable': 'PM2.5 Concentration',
#   'year': '2017'},
#  {'count': '10.37',
#   'dataset': 'Air Quality',
#   'date': '2017-01-01T00:00:00.000',
#   'geoid': '1400000US06037108201',
#   'location': '(34.2857885, -118.562083)',
#   'neighborhood': 'Porter Ranch',
#   'policy_area': 'Environment',
#   'row_id': 'PM2.5_Concentration_2017_1400000US06037108201',
#   'tract': 'Census Tract 1082.01, Los Angeles County, California',
#   'tract_number': '108201',
#   'variable': 'PM2.5 Concentration',
#   'year': '2017'},
#  {'count': '10.37',
#   'dataset': 'Air Quality',
#   'date': '2017-01-01T00:00:00.000',
#   'geoid': '1400000US06037108202',
#   'location': '(34.288396, -118.581814)',
#   'neighborhood': 'Chatsworth',
#   'policy_area': 'Environment',
#   'row_id': 'PM2.5_Concentration_2017_1400000US06037108202',
#   'tract': 'Census Tract 1082.02, Los Angeles County, California',
#   'tract_number': '108202',
#   'variable': 'PM2.5 Concentration',
#   'year': '2017'},
#  {'count': '11.21',
#   'dataset': 'Air Quality',
#   'date': '2017-01-01T00:00:00.000',
#   'geoid': '1400000US06037109100',
#   'location': '(34.278731, -118.4610295)',
#   'neighborhood': 'Mission Hills',
#   'policy_area': 'Environment',
#   'row_id': 'PM2.5_Concentration_2017_1400000US06037109100',
#   'tract': 'Census Tract 1091, Los Angeles County, California',
#   'tract_number': '109100',
#   'variable': 'PM2.5 Concentration',
#   'year': '2017'},
#  {'count': '11.21',
#   'dataset': 'Air Quality',
#   'date': '2017-01-01T00:00:00.000',
#   'geoid': '1400000US06037109200',
#   'location': '(34.2786785, -118.474608)',
#   'neighborhood': 'Granada Hills',
#   'policy_area': 'Environment',
#   'row_id': 'PM2.5_Concentration_2017_1400000US06037109200',
#   'tract': 'Census Tract 1092, Los Angeles County, California',
#   'tract_number': '109200',
#   'variable': 'PM2.5 Concentration',
#   'year': '2017'},
#  {'count': '11.21',
#   'dataset': 'Air Quality',
#   'date': '2017-01-01T00:00:00.000',
#   'geoid': '1400000US06037109300',
#   'location': '(34.272521, -118.479515)',
#   'neighborhood': 'Granada Hills',
#   'policy_area': 'Environment',
#   'row_id': 'PM2.5_Concentration_2017_1400000US06037109300',
#   'tract': 'Census Tract 1093, Los Angeles County, California',
#   'tract_number': '109300',
#   'variable': 'PM2.5 Concentration',
#   'year': '2017'},
#  {'count': '11.21',
#   'dataset': 'Air Quality',
#   'date': '2017-01-01T00:00:00.000',
#   'geoid': '1400000US06037109400',
#   'location': '(34.269881, -118.4552825)',
#   'neighborhood': 'Mission Hills',
#   'policy_area': 'Environment',
#   'row_id': 'PM2.5_Concentration_2017_1400000US06037109400',
#   'tract': 'Census Tract 1094, Los Angeles County, California',
#   'tract_number': '109400',
#   'variable': 'PM2.5 Concentration',
#   'year': '2017'},
#  {'count': '11.21',
#   'dataset': 'Air Quality',
#   'date': '2017-01-01T00:00:00.000',
#   'geoid': '1400000US06037109500',
#   'location': '(34.274036, -118.4444575)',
#   'neighborhood': 'San Fernando',
#   'policy_area': 'Environment',
#   'row_id': 'PM2.5_Concentration_2017_1400000US06037109500',
#   'tract': 'Census Tract 1095, Los Angeles County, California',
#   'tract_number': '109500',
#   'variable': 'PM2.5 Concentration',
#   'year': '2017'},
#  {'count': '11.21',
#   'dataset': 'Air Quality',
#   'date': '2017-01-01T00:00:00.000',
#   'geoid': '1400000US06037109601',
#   'location': '(34.2582765, -118.450367)',
#   'neighborhood': 'Mission Hills',
#   'policy_area': 'Environment',
#   'row_id': 'PM2.5_Concentration_2017_1400000US06037109601',
#   'tract': 'Census Tract 1096.01, Los Angeles County, California',
#   'tract_number': '109601',
#   'variable': 'PM2.5 Concentration',
#   'year': '2017'},
#  {'count': '11.21',
#   'dataset': 'Air Quality',
#   'date': '2017-01-01T00:00:00.000',
#   'geoid': '1400000US06037109603',
#   'location': '(34.2536515, -118.465415)',
#   'neighborhood': 'Mission Hills',
#   'policy_area': 'Environment',
#   'row_id': 'PM2.5_Concentration_2017_1400000US06037109603',
#   'tract': 'Census Tract 1096.03, Los Angeles County, California',
#   'tract_number': '109603',
#   'variable': 'PM2.5 Concentration',
#   'year': '2017'},
#  {'count': '11.21',
#   'dataset': 'Air Quality',
#   'date': '2017-01-01T00:00:00.000',
#   'geoid': '1400000US06037109604',
#   'location': '(34.2615535, -118.465347)',
#   'neighborhood': 'Mission Hills',
#   'policy_area': 'Environment',
#   'row_id': 'PM2.5_Concentration_2017_1400000US06037109604',
#   'tract': 'Census Tract 1096.04, Los Angeles County, California',
#   'tract_number': '109604',
#   'variable': 'PM2.5 Concentration',
#   'year': '2017'},
#  {'count': '10.79',
#   'dataset': 'Air Quality',
#   'date': '2017-01-01T00:00:00.000',
#   'geoid': '1400000US06037109700',
#   'location': '(34.263394, -118.4810215)',
#   'neighborhood': 'Granada Hills',
#   'policy_area': 'Environment',
#   'row_id': 'PM2.5_Concentration_2017_1400000US06037109700',
#   'tract': 'Census Tract 1097, Los Angeles County, California',
#   'tract_number': '109700',
#   'variable': 'PM2.5 Concentration',
#   'year': '2017'},
#  {'count': '10.79',
#   'dataset': 'Air Quality',
#   'date': '2017-01-01T00:00:00.000',
#   'geoid': '1400000US06037109800',
#   'location': '(34.2537535, -118.481817)',
#   'neighborhood': 'North Hills',
#   'policy_area': 'Environment',
#   'row_id': 'PM2.5_Concentration_2017_1400000US06037109800',
#   'tract': 'Census Tract 1098, Los Angeles County, California',
#   'tract_number': '109800',
#   'variable': 'PM2.5 Concentration',
#   'year': '2017'},
#  {'count': '10.79',
#   'dataset': 'Air Quality',
#   'date': '2017-01-01T00:00:00.000',
#   'geoid': '1400000US06037111100',
#   'location': '(34.2683575, -118.4946735)',
#   'neighborhood': 'Granada Hills',
#   'policy_area': 'Environment',
#   'row_id': 'PM2.5_Concentration_2017_1400000US06037111100',
#   'tract': 'Census Tract 1111, Los Angeles County, California',
#   'tract_number': '111100',
#   'variable': 'PM2.5 Concentration',
#   'year': '2017'},
#  {'count': '10.37',
#   'dataset': 'Air Quality',
#   'date': '2017-01-01T00:00:00.000',
#   'geoid': '1400000US06037111201',
#   'location': '(34.275029, -118.50855)',
#   'neighborhood': 'Granada Hills',
#   'policy_area': 'Environment',
#   'row_id': 'PM2.5_Concentration_2017_1400000US06037111201',
#   'tract': 'Census Tract 1112.01, Los Angeles County, California',
#   'tract_number': '111201',
#   'variable': 'PM2.5 Concentration',
#   'year': '2017'},
#  {'count': '10.37',
#   'dataset': 'Air Quality',
#   'date': '2017-01-01T00:00:00.000',
#   'geoid': '1400000US06037111202',
#   'location': '(34.2683485, -118.5151565)',
#   'neighborhood': 'Granada Hills',
#   'policy_area': 'Environment',
#   'row_id': 'PM2.5_Concentration_2017_1400000US06037111202',
#   'tract': 'Census Tract 1112.02, Los Angeles County, California',
#   'tract_number': '111202',
#   'variable': 'PM2.5 Concentration',
#   'year': '2017'},
#  {'count': '10.37',
#   'dataset': 'Air Quality',
#   'date': '2017-01-01T00:00:00.000',
#   'geoid': '1400000US06037111204',
#   'location': '(34.2620495, -118.5490485)',
#   'neighborhood': 'Porter Ranch',
#   'policy_area': 'Environment',
#   'row_id': 'PM2.5_Concentration_2017_1400000US06037111204',
#   'tract': 'Census Tract 1112.04, Los Angeles County, California',
#   'tract_number': '111204',
#   'variable': 'PM2.5 Concentration',
#   'year': '2017'},
#  {'count': '10.37',
#   'dataset': 'Air Quality',
#   'date': '2017-01-01T00:00:00.000',
#   'geoid': '1400000US06037111205',
#   'location': '(34.253636, -118.5358265)',
#   'neighborhood': 'Northridge',
#   'policy_area': 'Environment',
#   'row_id': 'PM2.5_Concentration_2017_1400000US06037111205',
#   'tract': 'Census Tract 1112.05, Los Angeles County, California',
#   'tract_number': '111205',
#   'variable': 'PM2.5 Concentration',
#   'year': '2017'},
#  {'count': '10.37',
#   'dataset': 'Air Quality',
#   'date': '2017-01-01T00:00:00.000',
#   'geoid': '1400000US06037111206',
#   'location': '(34.2676425, -118.5361955)',
#   'neighborhood': 'Porter Ranch',
#   'policy_area': 'Environment',
#   'row_id': 'PM2.5_Concentration_2017_1400000US06037111206',
#   'tract': 'Census Tract 1112.06, Los Angeles County, California',
#   'tract_number': '111206',
#   'variable': 'PM2.5 Concentration',
#   'year': '2017'},
#  {'count': '10.37',
#   'dataset': 'Air Quality',
#   'date': '2017-01-01T00:00:00.000',
#   'geoid': '1400000US06037111301',
#   'location': '(34.2610855, -118.5158815)',
#   'neighborhood': 'Granada Hills',
#   'policy_area': 'Environment',
#   'row_id': 'PM2.5_Concentration_2017_1400000US06037111301',
#   'tract': 'Census Tract 1113.01, Los Angeles County, California',
#   'tract_number': '111301',
#   'variable': 'PM2.5 Concentration',
#   'year': '2017'},
#  {'count': '10.37',
#   'dataset': 'Air Quality',
#   'date': '2017-01-01T00:00:00.000',
#   'geoid': '1400000US06037111302',
#   'location': '(34.2539425, -118.512829)',
#   'neighborhood': 'Northridge',
#   'policy_area': 'Environment',
#   'row_id': 'PM2.5_Concentration_2017_1400000US06037111302',
#   'tract': 'Census Tract 1113.02, Los Angeles County, California',
#   'tract_number': '111302',
#   'variable': 'PM2.5 Concentration',
#   'year': '2017'},
#  {'count': '10.37',
#   'dataset': 'Air Quality',
#   'date': '2017-01-01T00:00:00.000',
#   'geoid': '1400000US06037111400',
#   'location': '(34.257483, -118.495412)',
#   'neighborhood': 'Granada Hills',
#   'policy_area': 'Environment',
#   'row_id': 'PM2.5_Concentration_2017_1400000US06037111400',
#   'tract': 'Census Tract 1114, Los Angeles County, California',
#   'tract_number': '111400',
#   'variable': 'PM2.5 Concentration',
#   'year': '2017'},
#  {'count': '10.37',
#   'dataset': 'Air Quality',
#   'date': '2017-01-01T00:00:00.000',
#   'geoid': '1400000US06037113101',
#   'location': '(34.265338, -118.5882575)',
#   'neighborhood': 'Chatsworth',
#   'policy_area': 'Environment',
#   'row_id': 'PM2.5_Concentration_2017_1400000US06037113101',
#   'tract': 'Census Tract 1131.01, Los Angeles County, California',
#   'tract_number': '113101',
#   'variable': 'PM2.5 Concentration',
#   'year': '2017'},
#  {'count': '10.37',
#   'dataset': 'Air Quality',
#   'date': '2017-01-01T00:00:00.000',
#   'geoid': '1400000US06037113102',
#   'location': '(34.265325, -118.568068)',
#   'neighborhood': 'Chatsworth',
#   'policy_area': 'Environment',
#   'row_id': 'PM2.5_Concentration_2017_1400000US06037113102',
#   'tract': 'Census Tract 1131.02, Los Angeles County, California',
#   'tract_number': '113102',
#   'variable': 'PM2.5 Concentration',
#   'year': '2017'},
#  {'count': '9.95548266',
#   'dataset': 'Air Quality',
#   'date': '2017-01-01T00:00:00.000',
#   'geoid': '1400000US06037113211',
#   'location': '(34.2635755, -118.611966)',
#   'neighborhood': 'Chatsworth',
#   'policy_area': 'Environment',
#   'row_id': 'PM2.5_Concentration_2017_1400000US06037113211',
#   'tract': 'Census Tract 1132.11, Los Angeles County, California',
#   'tract_number': '113211',
#   'variable': 'PM2.5 Concentration',
#   'year': '2017'},
#  {'count': '10.37',
#   'dataset': 'Air Quality',
#   'date': '2017-01-01T00:00:00.000',
#   'geoid': '1400000US06037113212',
#   'location': '(34.2608605, -118.6035245)',
#   'neighborhood': 'Chatsworth',
#   'policy_area': 'Environment',
#   'row_id': 'PM2.5_Concentration_2017_1400000US06037113212',
#   'tract': 'Census Tract 1132.12, Los Angeles County, California',
#   'tract_number': '113212',
#   'variable': 'PM2.5 Concentration',
#   'year': '2017'},
#  {'count': '10.37',
#   'dataset': 'Air Quality',
#   'date': '2017-01-01T00:00:00.000',
#   'geoid': '1400000US06037113213',
#   'location': '(34.2535965, -118.608218)',
#   'neighborhood': 'Chatsworth',
#   'policy_area': 'Environment',
#   'row_id': 'PM2.5_Concentration_2017_1400000US06037113213',
#   'tract': 'Census Tract 1132.13, Los Angeles County, California',
#   'tract_number': '113213',
#   'variable': 'PM2.5 Concentration',
#   'year': '2017'},
#  {'count': '9.95548266',
#   'dataset': 'Air Quality',
#   'date': '2017-01-01T00:00:00.000',
#   'geoid': '1400000US06037113231',
#   'location': '(34.2282065, -118.645614)',
#   'neighborhood': 'Chatsworth Reservoir',
#   'policy_area': 'Environment',
#   'row_id': 'PM2.5_Concentration_2017_1400000US06037113231',
#   'tract': 'Census Tract 1132.31, Los Angeles County, California',
#   'tract_number': '113231',
#   'variable': 'PM2.5 Concentration',
#   'year': '2017'},
#  {'count': '10.37',
#   'dataset': 'Air Quality',
#   'date': '2017-01-01T00:00:00.000',
#   'geoid': '1400000US06037113232',
#   'location': '(34.227417, -118.61402)',
#   'neighborhood': 'West Hills',
#   'policy_area': 'Environment',
#   'row_id': 'PM2.5_Concentration_2017_1400000US06037113232',
#   'tract': 'Census Tract 1132.32, Los Angeles County, California',
#   'tract_number': '113232',
#   'variable': 'PM2.5 Concentration',
#   'year': '2017'},
#  {'count': '10.37',
#   'dataset': 'Air Quality',
#   'date': '2017-01-01T00:00:00.000',
#   'geoid': '1400000US06037113233',
#   'location': '(34.2275575, -118.6017175)',
#   'neighborhood': 'Canoga Park',
#   'policy_area': 'Environment',
#   'row_id': 'PM2.5_Concentration_2017_1400000US06037113233',
#   'tract': 'Census Tract 1132.33, Los Angeles County, California',
#   'tract_number': '113233',
#   'variable': 'PM2.5 Concentration',
#   'year': '2017'},
#  {'count': '10.37',
#   'dataset': 'Air Quality',
#   'date': '2017-01-01T00:00:00.000',
#   'geoid': '1400000US06037113234',
#   'location': '(34.227624, -118.59227)',
#   'neighborhood': 'Canoga Park',
#   'policy_area': 'Environment',
#   'row_id': 'PM2.5_Concentration_2017_1400000US06037113234',
#   'tract': 'Census Tract 1132.34, Los Angeles County, California',
#   'tract_number': '113234',
#   'variable': 'PM2.5 Concentration',
#   'year': '2017'},
#  {'count': '9.95548266',
#   'dataset': 'Air Quality',
#   'date': '2017-01-01T00:00:00.000',
#   'geoid': '1400000US06037113235',
#   'location': '(34.2373915, -118.6488335)',
#   'neighborhood': 'Chatsworth',
#   'policy_area': 'Environment',
#   'row_id': 'PM2.5_Concentration_2017_1400000US06037113235',
#   'tract': 'Census Tract 1132.35, Los Angeles County, California',
#   'tract_number': '113235',
#   'variable': 'PM2.5 Concentration',
#   'year': '2017'},
#  {'count': '9.95548266',
#   'dataset': 'Air Quality',
#   'date': '2017-01-01T00:00:00.000',
#   'geoid': '1400000US06037113237',
#   'location': '(34.2451855, -118.6125745)',
#   'neighborhood': 'Chatsworth',
#   'policy_area': 'Environment',
#   'row_id': 'PM2.5_Concentration_2017_1400000US06037113237',
#   'tract': 'Census Tract 1132.37, Los Angeles County, California',
#   'tract_number': '113237',
#   'variable': 'PM2.5 Concentration',
#   'year': '2017'},
#  {'count': '10.37',
#   'dataset': 'Air Quality',
#   'date': '2017-01-01T00:00:00.000',
#   'geoid': '1400000US06037113301',
#   'location': '(34.2448005, -118.5590895)',
#   'neighborhood': 'Northridge',
#   'policy_area': 'Environment',
#   'row_id': 'PM2.5_Concentration_2017_1400000US06037113301',
#   'tract': 'Census Tract 1133.01, Los Angeles County, California',
#   'tract_number': '113301',
#   'variable': 'PM2.5 Concentration',
#   'year': '2017'},
#  {'count': '10.37',
#   'dataset': 'Air Quality',
#   'date': '2017-01-01T00:00:00.000',
#   'geoid': '1400000US06037113303',
#   'location': '(34.2420235, -118.5801645)',
#   'neighborhood': 'Chatsworth',
#   'policy_area': 'Environment',
#   'row_id': 'PM2.5_Concentration_2017_1400000US06037113303',
#   'tract': 'Census Tract 1133.03, Los Angeles County, California',
#   'tract_number': '113303',
#   'variable': 'PM2.5 Concentration',
#   'year': '2017'},
#  {'count': '10.37',
#   'dataset': 'Air Quality',
#   'date': '2017-01-01T00:00:00.000',
#   'geoid': '1400000US06037113321',
#   'location': '(34.25361, -118.5913535)',
#   'neighborhood': 'Chatsworth',
#   'policy_area': 'Environment',
#   'row_id': 'PM2.5_Concentration_2017_1400000US06037113321',
#   'tract': 'Census Tract 1133.21, Los Angeles County, California',
#   'tract_number': '113321',
#   'variable': 'PM2.5 Concentration',
#   'year': '2017'},
#  {'count': '10.37',
#   'dataset': 'Air Quality',
#   'date': '2017-01-01T00:00:00.000',
#   'geoid': '1400000US06037113322',
#   'location': '(34.253622, -118.571362)',
#   'neighborhood': 'Chatsworth',
#   'policy_area': 'Environment',
#   'row_id': 'PM2.5_Concentration_2017_1400000US06037113322',
#   'tract': 'Census Tract 1133.22, Los Angeles County, California',
#   'tract_number': '113322',
#   'variable': 'PM2.5 Concentration',
#   'year': '2017'},
#  {'count': '10.37',
#   'dataset': 'Air Quality',
#   'date': '2017-01-01T00:00:00.000',
#   'geoid': '1400000US06037113401',
#   'location': '(34.2279845, -118.562301)',
#   'neighborhood': 'Winnetka',
#   'policy_area': 'Environment',
#   'row_id': 'PM2.5_Concentration_2017_1400000US06037113401',
#   'tract': 'Census Tract 1134.01, Los Angeles County, California',
#   'tract_number': '113401',
#   'variable': 'PM2.5 Concentration',
#   'year': '2017'},
#  {'count': '10.37',
#   'dataset': 'Air Quality',
#   'date': '2017-01-01T00:00:00.000',
#   'geoid': '1400000US06037113421',
#   'location': '(34.234694, -118.5826685)',
#   'neighborhood': 'Winnetka',
#   'policy_area': 'Environment',
#   'row_id': 'PM2.5_Concentration_2017_1400000US06037113421',
#   'tract': 'Census Tract 1134.21, Los Angeles County, California',
#   'tract_number': '113421',
#   'variable': 'PM2.5 Concentration',
#   'year': '2017'},
#  {'count': '10.37',
#   'dataset': 'Air Quality',
#   'date': '2017-01-01T00:00:00.000',
#   'geoid': '1400000US06037113422',
#   'location': '(34.224085, -118.5821745)',
#   'neighborhood': 'Winnetka',
#   'policy_area': 'Environment',
#   'row_id': 'PM2.5_Concentration_2017_1400000US06037113422',
#   'tract': 'Census Tract 1134.22, Los Angeles County, California',
#   'tract_number': '113422',
#   'variable': 'PM2.5 Concentration',
#   'year': '2017'},
#  {'count': '10.37',
#   'dataset': 'Air Quality',
#   'date': '2017-01-01T00:00:00.000',
#   'geoid': '1400000US06037115101',
#   'location': '(34.239435, -118.5112365)',
#   'neighborhood': 'Northridge',
#   'policy_area': 'Environment',
#   'row_id': 'PM2.5_Concentration_2017_1400000US06037115101',
#   'tract': 'Census Tract 1151.01, Los Angeles County, California',
#   'tract_number': '115101',
#   'variable': 'PM2.5 Concentration',
#   'year': '2017'},
#  {'count': '10.37',
#   'dataset': 'Air Quality',
#   'date': '2017-01-01T00:00:00.000',
#   'geoid': '1400000US06037115103',
#   'location': '(34.246414, -118.528551)',
#   'neighborhood': 'Northridge',
#   'policy_area': 'Environment',
#   'row_id': 'PM2.5_Concentration_2017_1400000US06037115103',
#   'tract': 'Census Tract 1151.03, Los Angeles County, California',
#   'tract_number': '115103',
#   'variable': 'PM2.5 Concentration',
#   'year': '2017'},
#  {'count': '10.37',
#   'dataset': 'Air Quality',
#   'date': '2017-01-01T00:00:00.000',
#   'geoid': '1400000US06037115104',
#   'location': '(34.2395005, -118.523595)',
#   'neighborhood': 'Northridge',
#   'policy_area': 'Environment',
#   'row_id': 'PM2.5_Concentration_2017_1400000US06037115104',
#   'tract': 'Census Tract 1151.04, Los Angeles County, California',
#   'tract_number': '115104',
#   'variable': 'PM2.5 Concentration',
#   'year': '2017'},
#  {'count': '10.37',
#   'dataset': 'Air Quality',
#   'date': '2017-01-01T00:00:00.000',
#   'geoid': '1400000US06037115201',
#   'location': '(34.244559, -118.537408)',
#   'neighborhood': 'Northridge',
#   'policy_area': 'Environment',
#   'row_id': 'PM2.5_Concentration_2017_1400000US06037115201',
#   'tract': 'Census Tract 1152.01, Los Angeles County, California',
#   'tract_number': '115201',
#   'variable': 'PM2.5 Concentration',
#   'year': '2017'},
#  {'count': '10.37',
#   'dataset': 'Air Quality',
#   'date': '2017-01-01T00:00:00.000',
#   'geoid': '1400000US06037115202',
#   'location': '(34.2338575, -118.537507)',
#   'neighborhood': 'Northridge',
#   'policy_area': 'Environment',
#   'row_id': 'PM2.5_Concentration_2017_1400000US06037115202',
#   'tract': 'Census Tract 1152.02, Los Angeles County, California',
#   'tract_number': '115202',
#   'variable': 'PM2.5 Concentration',
#   'year': '2017'},
#  {'count': '10.37',
#   'dataset': 'Air Quality',
#   'date': '2017-01-01T00:00:00.000',
#   'geoid': '1400000US06037115301',
#   'location': '(34.240482, -118.545339)',
#   'neighborhood': 'Northridge',
#   'policy_area': 'Environment',
#   'row_id': 'PM2.5_Concentration_2017_1400000US06037115301',
#   'tract': 'Census Tract 1153.01, Los Angeles County, California',
#   'tract_number': '115301',
#   'variable': 'PM2.5 Concentration',
#   'year': '2017'},
#  {'count': '10.37',
#   'dataset': 'Air Quality',
#   'date': '2017-01-01T00:00:00.000',
#   'geoid': '1400000US06037115302',
#   'location': '(34.226401, -118.5498615)',
#   'neighborhood': 'Northridge',
# ...
#   'row_id': 'PM2.5_Concentration_2017_1400000US06037294820',
#   'tract': 'Census Tract 2948.20, Los Angeles County, California',
#   'tract_number': '294820',
#   'variable': 'PM2.5 Concentration',
#   'year': '2017'},
#  {'count': '11.21',
#   'dataset': 'Air Quality',
#   'date': '2017-01-01T00:00:00.000',
#   'geoid': '1400000US06037294830',
#   'location': '(33.772277, -118.2673985)',
#   'neighborhood': 'Wilmington',
#   'policy_area': 'Environment',
#   'row_id': 'PM2.5_Concentration_2017_1400000US06037294830',
#   'tract': 'Census Tract 2948.30, Los Angeles County, California',
#   'tract_number': '294830',
#   'variable': 'PM2.5 Concentration',
#   'year': '2017'},
#  {'count': '11.21',
#   'dataset': 'Air Quality',
#   'date': '2017-01-01T00:00:00.000',
#   'geoid': '1400000US06037294900',
#   'location': '(33.773417, -118.2779635)',
#   'neighborhood': 'Wilmington',
#   'policy_area': 'Environment',
#   'row_id': 'PM2.5_Concentration_2017_1400000US06037294900',
#   'tract': 'Census Tract 2949, Los Angeles County, California',
#   'tract_number': '294900',
#   'variable': 'PM2.5 Concentration',
#   'year': '2017'},
#  {'count': '11.21',
#   'dataset': 'Air Quality',
#   'date': '2017-01-01T00:00:00.000',
#   'geoid': '1400000US06037295103',
#   'location': '(33.760268, -118.2968435)',
#   'neighborhood': 'San Pedro',
#   'policy_area': 'Environment',
#   'row_id': 'PM2.5_Concentration_2017_1400000US06037295103',
#   'tract': 'Census Tract 2951.03, Los Angeles County, California',
#   'tract_number': '295103',
#   'variable': 'PM2.5 Concentration',
#   'year': '2017'},
#  {'count': '11.21',
#   'dataset': 'Air Quality',
#   'date': '2017-01-01T00:00:00.000',
#   'geoid': '1400000US06037296210',
#   'location': '(33.748135, -118.283727)',
#   'neighborhood': 'San Pedro',
#   'policy_area': 'Environment',
#   'row_id': 'PM2.5_Concentration_2017_1400000US06037296210',
#   'tract': 'Census Tract 2962.10, Los Angeles County, California',
#   'tract_number': '296210',
#   'variable': 'PM2.5 Concentration',
#   'year': '2017'},
#  {'count': '11.21',
#   'dataset': 'Air Quality',
#   'date': '2017-01-01T00:00:00.000',
#   'geoid': '1400000US06037296220',
#   'location': '(33.74101, -118.2837425)',
#   'neighborhood': 'San Pedro',
#   'policy_area': 'Environment',
#   'row_id': 'PM2.5_Concentration_2017_1400000US06037296220',
#   'tract': 'Census Tract 2962.20, Los Angeles County, California',
#   'tract_number': '296220',
#   'variable': 'PM2.5 Concentration',
#   'year': '2017'},
#  {'count': '11.21',
#   'dataset': 'Air Quality',
#   'date': '2017-01-01T00:00:00.000',
#   'geoid': '1400000US06037296300',
#   'location': '(33.7536825, -118.300135)',
#   'neighborhood': 'San Pedro',
#   'policy_area': 'Environment',
#   'row_id': 'PM2.5_Concentration_2017_1400000US06037296300',
#   'tract': 'Census Tract 2963, Los Angeles County, California',
#   'tract_number': '296300',
#   'variable': 'PM2.5 Concentration',
#   'year': '2017'},
#  {'count': '11.21',
#   'dataset': 'Air Quality',
#   'date': '2017-01-01T00:00:00.000',
#   'geoid': '1400000US06037296401',
#   'location': '(33.7417575, -118.3143515)',
#   'neighborhood': 'San Pedro',
#   'policy_area': 'Environment',
#   'row_id': 'PM2.5_Concentration_2017_1400000US06037296401',
#   'tract': 'Census Tract 2964.01, Los Angeles County, California',
#   'tract_number': '296401',
#   'variable': 'PM2.5 Concentration',
#   'year': '2017'},
#  {'count': '11.21',
#   'dataset': 'Air Quality',
#   'date': '2017-01-01T00:00:00.000',
#   'geoid': '1400000US06037296402',
#   'location': '(33.7455135, -118.303183)',
#   'neighborhood': 'San Pedro',
#   'policy_area': 'Environment',
#   'row_id': 'PM2.5_Concentration_2017_1400000US06037296402',
#   'tract': 'Census Tract 2964.02, Los Angeles County, California',
#   'tract_number': '296402',
#   'variable': 'PM2.5 Concentration',
#   'year': '2017'},
#  {'count': '11.21',
#   'dataset': 'Air Quality',
#   'date': '2017-01-01T00:00:00.000',
#   'geoid': '1400000US06037296500',
#   'location': '(33.7480855, -118.2929285)',
#   'neighborhood': 'San Pedro',
#   'policy_area': 'Environment',
#   'row_id': 'PM2.5_Concentration_2017_1400000US06037296500',
#   'tract': 'Census Tract 2965, Los Angeles County, California',
#   'tract_number': '296500',
#   'variable': 'PM2.5 Concentration',
#   'year': '2017'},
#  {'count': '11.21',
#   'dataset': 'Air Quality',
#   'date': '2017-01-01T00:00:00.000',
#   'geoid': '1400000US06037296600',
#   'location': '(33.739883, -118.292314)',
#   'neighborhood': 'San Pedro',
#   'policy_area': 'Environment',
#   'row_id': 'PM2.5_Concentration_2017_1400000US06037296600',
#   'tract': 'Census Tract 2966, Los Angeles County, California',
#   'tract_number': '296600',
#   'variable': 'PM2.5 Concentration',
#   'year': '2017'},
#  {'count': '11.21',
#   'dataset': 'Air Quality',
#   'date': '2017-01-01T00:00:00.000',
#   'geoid': '1400000US06037296901',
#   'location': '(33.730163, -118.2945655)',
#   'neighborhood': 'San Pedro',
#   'policy_area': 'Environment',
#   'row_id': 'PM2.5_Concentration_2017_1400000US06037296901',
#   'tract': 'Census Tract 2969.01, Los Angeles County, California',
#   'tract_number': '296901',
#   'variable': 'PM2.5 Concentration',
#   'year': '2017'},
#  {'count': '11.21',
#   'dataset': 'Air Quality',
#   'date': '2017-01-01T00:00:00.000',
#   'geoid': '1400000US06037296902',
#   'location': '(33.7351435, -118.2945475)',
#   'neighborhood': 'San Pedro',
#   'policy_area': 'Environment',
#   'row_id': 'PM2.5_Concentration_2017_1400000US06037296902',
#   'tract': 'Census Tract 2969.02, Los Angeles County, California',
#   'tract_number': '296902',
#   'variable': 'PM2.5 Concentration',
#   'year': '2017'},
#  {'count': '11.21',
#   'dataset': 'Air Quality',
#   'date': '2017-01-01T00:00:00.000',
#   'geoid': '1400000US06037297000',
#   'location': '(33.7324785, -118.310758)',
#   'neighborhood': 'San Pedro',
#   'policy_area': 'Environment',
#   'row_id': 'PM2.5_Concentration_2017_1400000US06037297000',
#   'tract': 'Census Tract 2970, Los Angeles County, California',
#   'tract_number': '297000',
#   'variable': 'PM2.5 Concentration',
#   'year': '2017'},
#  {'count': '11.21',
#   'dataset': 'Air Quality',
#   'date': '2017-01-01T00:00:00.000',
#   'geoid': '1400000US06037297110',
#   'location': '(33.7346615, -118.284188)',
#   'neighborhood': 'San Pedro',
#   'policy_area': 'Environment',
#   'row_id': 'PM2.5_Concentration_2017_1400000US06037297110',
#   'tract': 'Census Tract 2971.10, Los Angeles County, California',
#   'tract_number': '297110',
#   'variable': 'PM2.5 Concentration',
#   'year': '2017'},
#  {'count': '11.21',
#   'dataset': 'Air Quality',
#   'date': '2017-01-01T00:00:00.000',
#   'geoid': '1400000US06037297120',
#   'location': '(33.727169, -118.284224)',
#   'neighborhood': 'San Pedro',
#   'policy_area': 'Environment',
#   'row_id': 'PM2.5_Concentration_2017_1400000US06037297120',
#   'tract': 'Census Tract 2971.20, Los Angeles County, California',
#   'tract_number': '297120',
#   'variable': 'PM2.5 Concentration',
#   'year': '2017'},
#  {'count': '11.21',
#   'dataset': 'Air Quality',
#   'date': '2017-01-01T00:00:00.000',
#   'geoid': '1400000US06037297201',
#   'location': '(33.7247115, -118.2912825)',
#   'neighborhood': 'San Pedro',
#   'policy_area': 'Environment',
#   'row_id': 'PM2.5_Concentration_2017_1400000US06037297201',
#   'tract': 'Census Tract 2972.01, Los Angeles County, California',
#   'tract_number': '297201',
#   'variable': 'PM2.5 Concentration',
#   'year': '2017'},
#  {'count': '11.21',
#   'dataset': 'Air Quality',
#   'date': '2017-01-01T00:00:00.000',
#   'geoid': '1400000US06037297202',
#   'location': '(33.724736, -118.299008)',
#   'neighborhood': 'San Pedro',
#   'policy_area': 'Environment',
#   'row_id': 'PM2.5_Concentration_2017_1400000US06037297202',
#   'tract': 'Census Tract 2972.02, Los Angeles County, California',
#   'tract_number': '297202',
#   'variable': 'PM2.5 Concentration',
#   'year': '2017'},
#  {'count': '11.21',
#   'dataset': 'Air Quality',
#   'date': '2017-01-01T00:00:00.000',
#   'geoid': '1400000US06037297300',
#   'location': '(33.72072214, -118.3123083)',
#   'neighborhood': 'San Pedro',
#   'policy_area': 'Environment',
#   'row_id': 'PM2.5_Concentration_2017_1400000US06037297300',
#   'tract': 'Census Tract 2973, Los Angeles County, California',
#   'tract_number': '297300',
#   'variable': 'PM2.5 Concentration',
#   'year': '2017'},
#  {'count': '11.21',
#   'dataset': 'Air Quality',
#   'date': '2017-01-01T00:00:00.000',
#   'geoid': '1400000US06037297400',
#   'location': '(33.7262015, -118.3220603)',
#   'neighborhood': 'San Pedro',
#   'policy_area': 'Environment',
#   'row_id': 'PM2.5_Concentration_2017_1400000US06037297400',
#   'tract': 'Census Tract 2974, Los Angeles County, California',
#   'tract_number': '297400',
#   'variable': 'PM2.5 Concentration',
#   'year': '2017'},
#  {'count': '11.21',
#   'dataset': 'Air Quality',
#   'date': '2017-01-01T00:00:00.000',
#   'geoid': '1400000US06037297500',
#   'location': '(33.713354, -118.3018828)',
#   'neighborhood': 'San Pedro',
#   'policy_area': 'Environment',
#   'row_id': 'PM2.5_Concentration_2017_1400000US06037297500',
#   'tract': 'Census Tract 2975, Los Angeles County, California',
#   'tract_number': '297500',
#   'variable': 'PM2.5 Concentration',
#   'year': '2017'},
#  {'count': '11.21',
#   'dataset': 'Air Quality',
#   'date': '2017-01-01T00:00:00.000',
#   'geoid': '1400000US06037297601',
#   'location': '(33.71456779, -118.2879352)',
#   'neighborhood': 'San Pedro',
#   'policy_area': 'Environment',
#   'row_id': 'PM2.5_Concentration_2017_1400000US06037297601',
#   'tract': 'Census Tract 2976.01, Los Angeles County, California',
#   'tract_number': '297601',
#   'variable': 'PM2.5 Concentration',
#   'year': '2017'},
#  {'count': '11.21',
#   'dataset': 'Air Quality',
#   'date': '2017-01-01T00:00:00.000',
#   'geoid': '1400000US06037297602',
#   'location': '(33.7162305, -118.2903905)',
#   'neighborhood': 'San Pedro',
#   'policy_area': 'Environment',
#   'row_id': 'PM2.5_Concentration_2017_1400000US06037297602',
#   'tract': 'Census Tract 2976.02, Los Angeles County, California',
#   'tract_number': '297602',
#   'variable': 'PM2.5 Concentration',
#   'year': '2017'},
#  {'count': '10.79',
#   'dataset': 'Air Quality',
#   'date': '2017-01-01T00:00:00.000',
#   'geoid': '1400000US06037300100',
#   'location': '(34.240611, -118.235107)',
#   'neighborhood': 'La Crescenta-Montrose',
#   'policy_area': 'Environment',
#   'row_id': 'PM2.5_Concentration_2017_1400000US06037300100',
#   'tract': 'Census Tract 3001, Los Angeles County, California',
#   'tract_number': '300100',
#   'variable': 'PM2.5 Concentration',
#   'year': '2017'},
#  {'count': '11.21',
#   'dataset': 'Air Quality',
#   'date': '2017-01-01T00:00:00.000',
#   'geoid': '1400000US06037300200',
#   'location': '(34.228725, -118.237835)',
#   'neighborhood': 'La Crescenta-Montrose',
#   'policy_area': 'Environment',
#   'row_id': 'PM2.5_Concentration_2017_1400000US06037300200',
#   'tract': 'Census Tract 3002, Los Angeles County, California',
#   'tract_number': '300200',
#   'variable': 'PM2.5 Concentration',
#   'year': '2017'},
#  {'count': '10.79',
#   'dataset': 'Air Quality',
#   'date': '2017-01-01T00:00:00.000',
#   'geoid': '1400000US06037300301',
#   'location': '(34.248378, -118.2527395)',
#   'neighborhood': 'Glendale',
#   'policy_area': 'Environment',
#   'row_id': 'PM2.5_Concentration_2017_1400000US06037300301',
#   'tract': 'Census Tract 3003.01, Los Angeles County, California',
#   'tract_number': '300301',
#   'variable': 'PM2.5 Concentration',
#   'year': '2017'},
#  {'count': '11.21',
#   'dataset': 'Air Quality',
#   'date': '2017-01-01T00:00:00.000',
#   'geoid': '1400000US06037300400',
#   'location': '(34.228257, -118.25731)',
#   'neighborhood': 'Glendale',
#   'policy_area': 'Environment',
#   'row_id': 'PM2.5_Concentration_2017_1400000US06037300400',
#   'tract': 'Census Tract 3004, Los Angeles County, California',
#   'tract_number': '300400',
#   'variable': 'PM2.5 Concentration',
#   'year': '2017'},
#  {'count': '11.21',
#   'dataset': 'Air Quality',
#   'date': '2017-01-01T00:00:00.000',
#   'geoid': '1400000US06037300501',
#   'location': '(34.2212985, -118.239588)',
#   'neighborhood': 'La Crescenta-Montrose',
#   'policy_area': 'Environment',
#   'row_id': 'PM2.5_Concentration_2017_1400000US06037300501',
#   'tract': 'Census Tract 3005.01, Los Angeles County, California',
#   'tract_number': '300501',
#   'variable': 'PM2.5 Concentration',
#   'year': '2017'},
#  {'count': '11.21',
#   'dataset': 'Air Quality',
#   'date': '2017-01-01T00:00:00.000',
#   'geoid': '1400000US06037300502',
#   'location': '(34.2117495, -118.225292)',
#   'neighborhood': 'La Crescenta-Montrose',
#   'policy_area': 'Environment',
#   'row_id': 'PM2.5_Concentration_2017_1400000US06037300502',
#   'tract': 'Census Tract 3005.02, Los Angeles County, California',
#   'tract_number': '300502',
#   'variable': 'PM2.5 Concentration',
#   'year': '2017'},
#  {'count': '11.21',
#   'dataset': 'Air Quality',
#   'date': '2017-01-01T00:00:00.000',
#   'geoid': '1400000US06037300600',
#   'location': '(34.2067165, -118.2368375)',
#   'neighborhood': 'Glendale',
#   'policy_area': 'Environment',
#   'row_id': 'PM2.5_Concentration_2017_1400000US06037300600',
#   'tract': 'Census Tract 3006, Los Angeles County, California',
#   'tract_number': '300600',
#   'variable': 'PM2.5 Concentration',
#   'year': '2017'},
#  {'count': '11.63',
#   'dataset': 'Air Quality',
#   'date': '2017-01-01T00:00:00.000',
#   'geoid': '1400000US06037300701',
#   'location': '(34.202483, -118.2588315)',
#   'neighborhood': 'Glendale',
#   'policy_area': 'Environment',
#   'row_id': 'PM2.5_Concentration_2017_1400000US06037300701',
#   'tract': 'Census Tract 3007.01, Los Angeles County, California',
#   'tract_number': '300701',
#   'variable': 'PM2.5 Concentration',
#   'year': '2017'},
#  {'count': '11.63',
#   'dataset': 'Air Quality',
#   'date': '2017-01-01T00:00:00.000',
#   'geoid': '1400000US06037300702',
#   'location': '(34.1907305, -118.2577215)',
#   'neighborhood': 'Glendale',
#   'policy_area': 'Environment',
#   'row_id': 'PM2.5_Concentration_2017_1400000US06037300702',
#   'tract': 'Census Tract 3007.02, Los Angeles County, California',
#   'tract_number': '300702',
#   'variable': 'PM2.5 Concentration',
#   'year': '2017'},
#  {'count': '11.63',
#   'dataset': 'Air Quality',
#   'date': '2017-01-01T00:00:00.000',
#   'geoid': '1400000US06037300800',
#   'location': '(34.1850915, -118.219529)',
#   'neighborhood': 'Glendale',
#   'policy_area': 'Environment',
#   'row_id': 'PM2.5_Concentration_2017_1400000US06037300800',
#   'tract': 'Census Tract 3008, Los Angeles County, California',
#   'tract_number': '300800',
#   'variable': 'PM2.5 Concentration',
#   'year': '2017'},
#  {'count': '11.63',
#   'dataset': 'Air Quality',
#   'date': '2017-01-01T00:00:00.000',
#   'geoid': '1400000US06037300901',
#   'location': '(34.1693925, -118.206797)',
#   'neighborhood': 'Glendale',
#   'policy_area': 'Environment',
#   'row_id': 'PM2.5_Concentration_2017_1400000US06037300901',
#   'tract': 'Census Tract 3009.01, Los Angeles County, California',
#   'tract_number': '300901',
#   'variable': 'PM2.5 Concentration',
#   'year': '2017'},
#  {'count': '11.63',
#   'dataset': 'Air Quality',
#   'date': '2017-01-01T00:00:00.000',
#   'geoid': '1400000US06037300902',
#   'location': '(34.155939, -118.203587)',
#   'neighborhood': 'Glendale',
#   'policy_area': 'Environment',
#   'row_id': 'PM2.5_Concentration_2017_1400000US06037300902',
#   'tract': 'Census Tract 3009.02, Los Angeles County, California',
#   'tract_number': '300902',
#   'variable': 'PM2.5 Concentration',
#   'year': '2017'},
#  {'count': '12.05',
#   'dataset': 'Air Quality',
#   'date': '2017-01-01T00:00:00.000',
#   'geoid': '1400000US06037301000',
#   'location': '(34.1564305, -118.2329335)',
#   'neighborhood': 'Glendale',
#   'policy_area': 'Environment',
#   'row_id': 'PM2.5_Concentration_2017_1400000US06037301000',
#   'tract': 'Census Tract 3010, Los Angeles County, California',
#   'tract_number': '301000',
#   'variable': 'PM2.5 Concentration',
#   'year': '2017'},
#  {'count': '12.05',
#   'dataset': 'Air Quality',
#   'date': '2017-01-01T00:00:00.000',
#   'geoid': '1400000US06037301100',
#   'location': '(34.1621815, -118.2441095)',
#   'neighborhood': 'Glendale',
#   'policy_area': 'Environment',
#   'row_id': 'PM2.5_Concentration_2017_1400000US06037301100',
#   'tract': 'Census Tract 3011, Los Angeles County, California',
#   'tract_number': '301100',
#   'variable': 'PM2.5 Concentration',
#   'year': '2017'}]

# %%
# # Initialize a list that will eventually be used for form the columns in dataframe.
# count = []
# dataset = []
# date = []
# geoid = []
# location = []
# lat = []
# lng = []
# neighborhood = []
# policy_area = []
# row_id = []
# tract = []
# tract_number = []
# variable = []
# year = []


# for yr in years:
#     query_url = f"{url}{yr}"
#     response = requests.get(query_url)
#     response_json = response.json()
    
#     for key in range(len(response_json)):
#         count.append(response_json[key]['count'])
#         dataset.append(response_json[key]['dataset'])
#         date.append(response_json[key]['date'])
#         geoid.append(response_json[key]['geoid'])
#         location.append(response_json[key]['location'])
#         neighborhood.append(response_json[key]['neighborhood'])
#         policy_area.append(response_json[key]['policy_area'])
#         row_id.append(response_json[key]['row_id'])
#         tract.append(response_json[key]['tract'])
#         tract_number.append(response_json[key]['tract_number'])
#         variable.append(response_json[key]['variable'])
#         year.append(response_json[key]['year'])
